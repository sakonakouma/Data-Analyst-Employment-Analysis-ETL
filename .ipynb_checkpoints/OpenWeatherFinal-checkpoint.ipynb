# %%
# Dependencies and Setup
import json
from pandas.io.json import json_normalize
import pandas as pd
import numpy as np
import time
import csv
import re
import os
import configparser
import requests

# Import API key
from config import weather_key

# %%
# Import city list
top50city_df = pd.read_csv("./output_data/top50city.csv")

# %%
# run first list of 20 city codes
url="https://api.openweathermap.org/data/2.5/group?id= 5128581,5295985,4887398,5391959,4671654,4460243,4699066,4704482,4726311,5131095,5186794,4726206,5392171,5308655,5099836,5317058,5809844,4509177,4700168,4719457&appid=" + weather_key + "&units=metric"

# %%
# Using this method to load
response = requests.get(url)
response.json()
# Out:
# {'cnt': 19,
#  'list': [{'coord': {'lon': -112.19, 'lat': 33.54},
#    'sys': {'country': 'US',
#     'timezone': -25200,
#     'sunrise': 1597063679,
#     'sunset': 1597112412},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'main': {'temp': 40.87,
#     'feels_like': 35.93,
#     'temp_min': 39.44,
#     'temp_max': 42.22,
#     'pressure': 1009,
#     'humidity': 9},
#    'visibility': 10000,
#    'wind': {'speed': 4.6, 'deg': 280},
#    'clouds': {'all': 1},
#    'dt': 1597112133,
#    'id': 5295985,
#    'name': 'Glendale'},
#   {'coord': {'lon': -87.65, 'lat': 41.85},
#    'sys': {'country': 'US',
#     'timezone': -18000,
#     'sunrise': 1597056852,
#     'sunset': 1597107461},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'main': {'temp': 22.01,
#     'feels_like': 21.67,
#     'temp_min': 21.11,
#     'temp_max': 22.78,
#     'pressure': 1013,
#     'humidity': 83},
#    'visibility': 10000,
#    'wind': {'speed': 5.1, 'deg': 310},
#    'clouds': {'all': 40},
#    'dt': 1597112114,
#    'id': 4887398,
#    'name': 'Chicago'},
#   {'coord': {'lon': -122.42, 'lat': 37.77},
#    'sys': {'country': 'US',
#     'timezone': -25200,
#     'sunrise': 1597065689,
#     'sunset': 1597115311},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'main': {'temp': 16.11,
#     'feels_like': 11.52,
#     'temp_min': 13.89,
#     'temp_max': 19,
#     'pressure': 1012,
#     'humidity': 68},
#    'visibility': 10000,
#    'wind': {'speed': 6.7, 'deg': 320},
#    'clouds': {'all': 20},
#    'dt': 1597112136,
#    'id': 5391959,
#    'name': 'San Francisco'},
#   {'coord': {'lon': -97.74, 'lat': 30.27},
#    'sys': {'country': 'US',
#     'timezone': -18000,
#     'sunrise': 1597060522,
#     'sunset': 1597108633},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'main': {'temp': 32.04,
#     'feels_like': 32.5,
#     'temp_min': 31.11,
#     'temp_max': 33,
#     'pressure': 1014,
#     'humidity': 49},
#    'visibility': 10000,
#    'wind': {'speed': 4.6, 'deg': 150},
#    'clouds': {'all': 5},
#    'dt': 1597112104,
#    'id': 4671654,
#    'name': 'Austin'},
#   {'coord': {'lon': -80.84, 'lat': 35.23},
#    'sys': {'country': 'US',
#     'timezone': -14400,
#     'sunrise': 1597055979,
#     'sunset': 1597105065},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'main': {'temp': 24.19,
#     'feels_like': 26.96,
#     'temp_min': 23.33,
#     'temp_max': 24.44,
#     'pressure': 1016,
#     'humidity': 83},
#    'visibility': 10000,
#    'wind': {'speed': 2.1, 'deg': 200},
#    'clouds': {'all': 20},
#    'dt': 1597112096,
#    'id': 4460243,
#    'name': 'Charlotte'},
#   {'coord': {'lon': -95.36, 'lat': 29.76},
#    'sys': {'country': 'US',
#     'timezone': -18000,
#     'sunrise': 1597059998,
#     'sunset': 1597108015},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'main': {'temp': 30.03,
#     'feels_like': 32.8,
#     'temp_min': 29,
#     'temp_max': 31.11,
#     'pressure': 1015,
#     'humidity': 74},
#    'visibility': 10000,
#    'wind': {'speed': 5.1, 'deg': 150},
#    'clouds': {'all': 1},
#    'dt': 1597112110,
#    'id': 4699066,
#    'name': 'Houston'},
#   {'coord': {'lon': -97.03, 'lat': 33.12},
#    'sys': {'country': 'US',
#     'timezone': -18000,
#     'sunrise': 1597060080,
#     'sunset': 1597108734},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'main': {'temp': 33.1,
#     'feels_like': 33.03,
#     'temp_min': 32,
#     'temp_max': 33.89,
#     'pressure': 1012,
#     'humidity': 43},
#    'visibility': 10000,
#    'wind': {'speed': 4.6, 'deg': 150},
#    'clouds': {'all': 1},
#    'dt': 1597112110,
#    'id': 4704482,
#    'name': 'Lake Dallas'},
#   {'coord': {'lon': -98.24, 'lat': 27.76},
#    'sys': {'country': 'US',
#     'timezone': -18000,
#     'sunrise': 1597060868,
#     'sunset': 1597108527},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'main': {'temp': 30.01,
#     'feels_like': 30.33,
#     'temp_min': 29,
#     'temp_max': 31,
#     'pressure': 1014,
#     'humidity': 62},
#    'visibility': 10000,
#    'wind': {'speed': 6.2, 'deg': 140},
#    'clouds': {'all': 1},
#    'dt': 1597112111,
#    'id': 4726311,
#    'name': 'San Diego'},
#   {'coord': {'lon': -75.71, 'lat': 44.15},
#    'sys': {'country': 'US',
#     'timezone': -14400,
#     'sunrise': 1597053678,
#     'sunset': 1597104904},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'main': {'temp': 22.67,
#     'feels_like': 24.72,
#     'temp_min': 21.67,
#     'temp_max': 24,
#     'pressure': 1014,
#     'humidity': 83},
#    'visibility': 10000,
#    'wind': {'speed': 2.1, 'deg': 190},
#    'clouds': {'all': 1},
#    'dt': 1597112126,
#    'id': 5131095,
#    'name': 'Philadelphia'},
#   {'coord': {'lon': -76.14, 'lat': 40.23},
#    'sys': {'country': 'US',
#     'timezone': -14400,
#     'sunrise': 1597054289,
#     'sunset': 1597104499},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'main': {'temp': 26.05,
#     'feels_like': 29.07,
#     'temp_min': 25,
#     'temp_max': 26.67,
#     'pressure': 1015,
#     'humidity': 79},
#    'visibility': 10000,
#    'wind': {'speed': 2.49, 'deg': 189},
#    'clouds': {'all': 0},
#    'dt': 1597112128,
#    'id': 5186794,
#    'name': 'Denver'},
#   {'coord': {'lon': -98.49, 'lat': 29.42},
#    'sys': {'country': 'US',
#     'timezone': -18000,
#     'sunrise': 1597060780,
#     'sunset': 1597108735},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'main': {'temp': 32.6,
#     'feels_like': 31.62,
#     'temp_min': 31.67,
#     'temp_max': 33.33,
#     'pressure': 1013,
#     'humidity': 52},
#    'visibility': 10000,
#    'wind': {'speed': 7.7, 'deg': 150},
#    'clouds': {'all': 1},
#    'dt': 1597112111,
#    'id': 4726206,
#    'name': 'San Antonio'},
#   {'coord': {'lon': -121.89, 'lat': 37.34},
#    'sys': {'country': 'US',
#     'timezone': -25200,
#     'sunrise': 1597065610,
#     'sunset': 1597115136},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'main': {'temp': 23.08,
#     'feels_like': 19.66,
#     'temp_min': 21.11,
#     'temp_max': 25,
#     'pressure': 1011,
#     'humidity': 53},
#    'visibility': 10000,
#    'wind': {'speed': 6.2, 'deg': 320},
#    'clouds': {'all': 20},
#    'dt': 1597112136,
#    'id': 5392171,
#    'name': 'San Jose'},
#   {'coord': {'lon': -112.07, 'lat': 33.45},
#    'sys': {'country': 'US',
#     'timezone': -25200,
#     'sunrise': 1597063659,
#     'sunset': 1597112374},
#    'weather': [{'id': 711,
#      'main': 'Smoke',
#      'description': 'smoke',
#      'icon': '50d'}],
#    'main': {'temp': 40.78,
#     'feels_like': 35.48,
#     'temp_min': 39.44,
#     'temp_max': 42.22,
#     'pressure': 1007,
#     'humidity': 9},
#    'visibility': 10000,
#    'wind': {'speed': 5.1, 'deg': 260},
#    'clouds': {'all': 20},
#    'dt': 1597112133,
#    'id': 5308655,
#    'name': 'Phoenix'},
#   {'coord': {'lon': -74.08, 'lat': 40.73},
#    'sys': {'country': 'US',
#     'timezone': -14400,
#     'sunrise': 1597053733,
#     'sunset': 1597104066},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'main': {'temp': 28.36,
#     'feels_like': 31.43,
#     'temp_min': 25.56,
#     'temp_max': 30,
#     'pressure': 1015,
#     'humidity': 70},
#    'visibility': 10000,
#    'wind': {'speed': 2.6, 'deg': 210},
#    'clouds': {'all': 20},
#    'dt': 1597112122,
#    'id': 5099836,
#    'name': 'Jersey City'},
#   {'coord': {'lon': -111.91, 'lat': 33.41},
#    'sys': {'country': 'US',
#     'timezone': -25200,
#     'sunrise': 1597063624,
#     'sunset': 1597112332},
#    'weather': [{'id': 711,
#      'main': 'Smoke',
#      'description': 'smoke',
#      'icon': '50d'}],
#    'main': {'temp': 40.78,
#     'feels_like': 35.48,
#     'temp_min': 40,
#     'temp_max': 42,
#     'pressure': 1007,
#     'humidity': 9},
#    'visibility': 10000,
#    'wind': {'speed': 5.1, 'deg': 260},
#    'clouds': {'all': 20},
#    'dt': 1597112133,
#    'id': 5317058,
#    'name': 'Tempe'},
#   {'coord': {'lon': -122.33, 'lat': 47.61},
#    'sys': {'country': 'US',
#     'timezone': -25200,
#     'sunrise': 1597064362,
#     'sunset': 1597116595},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'main': {'temp': 23.87,
#     'feels_like': 21.69,
#     'temp_min': 21.67,
#     'temp_max': 26,
#     'pressure': 1015,
#     'humidity': 41},
#    'visibility': 10000,
#    'wind': {'speed': 3.1, 'deg': 320},
#    'clouds': {'all': 1},
#    'dt': 1597112144,
#    'id': 5809844,
#    'name': 'Seattle'},
#   {'coord': {'lon': -83, 'lat': 39.96},
#    'sys': {'country': 'US',
#     'timezone': -14400,
#     'sunrise': 1597055969,
#     'sunset': 1597106112},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'main': {'temp': 25.94,
#     'feels_like': 27.37,
#     'temp_min': 24.44,
#     'temp_max': 27.22,
#     'pressure': 1015,
#     'humidity': 69},
#    'visibility': 10000,
#    'wind': {'speed': 3.1, 'deg': 230},
#    'clouds': {'all': 20},
#    'dt': 1597112096,
#    'id': 4509177,
#    'name': 'Columbus'},
#   {'coord': {'lon': -96.95, 'lat': 32.81},
#    'sys': {'country': 'US',
#     'timezone': -18000,
#     'sunrise': 1597060091,
#     'sunset': 1597108684},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'main': {'temp': 33.37,
#     'feels_like': 33.41,
#     'temp_min': 32.78,
#     'temp_max': 34,
#     'pressure': 1012,
#     'humidity': 43},
#    'visibility': 10000,
#    'wind': {'speed': 4.6, 'deg': 160},
#    'clouds': {'all': 20},
#    'dt': 1597112110,
#    'id': 4700168,
#    'name': 'Irving'},
#   {'coord': {'lon': -96.7, 'lat': 33.02},
#    'sys': {'country': 'US',
#     'timezone': -18000,
#     'sunrise': 1597060011,
#     'sunset': 1597108645},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'main': {'temp': 32.87,
#     'feels_like': 30.44,
#     'temp_min': 31.67,
#     'temp_max': 34,
#     'pressure': 1013,
#     'humidity': 36},
#    'visibility': 10000,
#    'wind': {'speed': 6.2, 'deg': 180},
#    'clouds': {'all': 5},
#    'dt': 1597112110,
#    'id': 4719457,
#    'name': 'Plano'}]}

# %%
#
response.json().keys()

#JSON response
response.json()['list']
# Out:
# [{'coord': {'lon': -112.19, 'lat': 33.54},
#   'sys': {'country': 'US',
#    'timezone': -25200,
#    'sunrise': 1597063679,
#    'sunset': 1597112412},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'main': {'temp': 40.87,
#    'feels_like': 35.93,
#    'temp_min': 39.44,
#    'temp_max': 42.22,
#    'pressure': 1009,
#    'humidity': 9},
#   'visibility': 10000,
#   'wind': {'speed': 4.6, 'deg': 280},
#   'clouds': {'all': 1},
#   'dt': 1597112133,
#   'id': 5295985,
#   'name': 'Glendale'},
#  {'coord': {'lon': -87.65, 'lat': 41.85},
#   'sys': {'country': 'US',
#    'timezone': -18000,
#    'sunrise': 1597056852,
#    'sunset': 1597107461},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'main': {'temp': 22.01,
#    'feels_like': 21.67,
#    'temp_min': 21.11,
#    'temp_max': 22.78,
#    'pressure': 1013,
#    'humidity': 83},
#   'visibility': 10000,
#   'wind': {'speed': 5.1, 'deg': 310},
#   'clouds': {'all': 40},
#   'dt': 1597112114,
#   'id': 4887398,
#   'name': 'Chicago'},
#  {'coord': {'lon': -122.42, 'lat': 37.77},
#   'sys': {'country': 'US',
#    'timezone': -25200,
#    'sunrise': 1597065689,
#    'sunset': 1597115311},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'main': {'temp': 16.11,
#    'feels_like': 11.52,
#    'temp_min': 13.89,
#    'temp_max': 19,
#    'pressure': 1012,
#    'humidity': 68},
#   'visibility': 10000,
#   'wind': {'speed': 6.7, 'deg': 320},
#   'clouds': {'all': 20},
#   'dt': 1597112136,
#   'id': 5391959,
#   'name': 'San Francisco'},
#  {'coord': {'lon': -97.74, 'lat': 30.27},
#   'sys': {'country': 'US',
#    'timezone': -18000,
#    'sunrise': 1597060522,
#    'sunset': 1597108633},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'main': {'temp': 32.04,
#    'feels_like': 32.5,
#    'temp_min': 31.11,
#    'temp_max': 33,
#    'pressure': 1014,
#    'humidity': 49},
#   'visibility': 10000,
#   'wind': {'speed': 4.6, 'deg': 150},
#   'clouds': {'all': 5},
#   'dt': 1597112104,
#   'id': 4671654,
#   'name': 'Austin'},
#  {'coord': {'lon': -80.84, 'lat': 35.23},
#   'sys': {'country': 'US',
#    'timezone': -14400,
#    'sunrise': 1597055979,
#    'sunset': 1597105065},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'main': {'temp': 24.19,
#    'feels_like': 26.96,
#    'temp_min': 23.33,
#    'temp_max': 24.44,
#    'pressure': 1016,
#    'humidity': 83},
#   'visibility': 10000,
#   'wind': {'speed': 2.1, 'deg': 200},
#   'clouds': {'all': 20},
#   'dt': 1597112096,
#   'id': 4460243,
#   'name': 'Charlotte'},
#  {'coord': {'lon': -95.36, 'lat': 29.76},
#   'sys': {'country': 'US',
#    'timezone': -18000,
#    'sunrise': 1597059998,
#    'sunset': 1597108015},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'main': {'temp': 30.03,
#    'feels_like': 32.8,
#    'temp_min': 29,
#    'temp_max': 31.11,
#    'pressure': 1015,
#    'humidity': 74},
#   'visibility': 10000,
#   'wind': {'speed': 5.1, 'deg': 150},
#   'clouds': {'all': 1},
#   'dt': 1597112110,
#   'id': 4699066,
#   'name': 'Houston'},
#  {'coord': {'lon': -97.03, 'lat': 33.12},
#   'sys': {'country': 'US',
#    'timezone': -18000,
#    'sunrise': 1597060080,
#    'sunset': 1597108734},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'main': {'temp': 33.1,
#    'feels_like': 33.03,
#    'temp_min': 32,
#    'temp_max': 33.89,
#    'pressure': 1012,
#    'humidity': 43},
#   'visibility': 10000,
#   'wind': {'speed': 4.6, 'deg': 150},
#   'clouds': {'all': 1},
#   'dt': 1597112110,
#   'id': 4704482,
#   'name': 'Lake Dallas'},
#  {'coord': {'lon': -98.24, 'lat': 27.76},
#   'sys': {'country': 'US',
#    'timezone': -18000,
#    'sunrise': 1597060868,
#    'sunset': 1597108527},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'main': {'temp': 30.01,
#    'feels_like': 30.33,
#    'temp_min': 29,
#    'temp_max': 31,
#    'pressure': 1014,
#    'humidity': 62},
#   'visibility': 10000,
#   'wind': {'speed': 6.2, 'deg': 140},
#   'clouds': {'all': 1},
#   'dt': 1597112111,
#   'id': 4726311,
#   'name': 'San Diego'},
#  {'coord': {'lon': -75.71, 'lat': 44.15},
#   'sys': {'country': 'US',
#    'timezone': -14400,
#    'sunrise': 1597053678,
#    'sunset': 1597104904},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'main': {'temp': 22.67,
#    'feels_like': 24.72,
#    'temp_min': 21.67,
#    'temp_max': 24,
#    'pressure': 1014,
#    'humidity': 83},
#   'visibility': 10000,
#   'wind': {'speed': 2.1, 'deg': 190},
#   'clouds': {'all': 1},
#   'dt': 1597112126,
#   'id': 5131095,
#   'name': 'Philadelphia'},
#  {'coord': {'lon': -76.14, 'lat': 40.23},
#   'sys': {'country': 'US',
#    'timezone': -14400,
#    'sunrise': 1597054289,
#    'sunset': 1597104499},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'main': {'temp': 26.05,
#    'feels_like': 29.07,
#    'temp_min': 25,
#    'temp_max': 26.67,
#    'pressure': 1015,
#    'humidity': 79},
#   'visibility': 10000,
#   'wind': {'speed': 2.49, 'deg': 189},
#   'clouds': {'all': 0},
#   'dt': 1597112128,
#   'id': 5186794,
#   'name': 'Denver'},
#  {'coord': {'lon': -98.49, 'lat': 29.42},
#   'sys': {'country': 'US',
#    'timezone': -18000,
#    'sunrise': 1597060780,
#    'sunset': 1597108735},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'main': {'temp': 32.6,
#    'feels_like': 31.62,
#    'temp_min': 31.67,
#    'temp_max': 33.33,
#    'pressure': 1013,
#    'humidity': 52},
#   'visibility': 10000,
#   'wind': {'speed': 7.7, 'deg': 150},
#   'clouds': {'all': 1},
#   'dt': 1597112111,
#   'id': 4726206,
#   'name': 'San Antonio'},
#  {'coord': {'lon': -121.89, 'lat': 37.34},
#   'sys': {'country': 'US',
#    'timezone': -25200,
#    'sunrise': 1597065610,
#    'sunset': 1597115136},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'main': {'temp': 23.08,
#    'feels_like': 19.66,
#    'temp_min': 21.11,
#    'temp_max': 25,
#    'pressure': 1011,
#    'humidity': 53},
#   'visibility': 10000,
#   'wind': {'speed': 6.2, 'deg': 320},
#   'clouds': {'all': 20},
#   'dt': 1597112136,
#   'id': 5392171,
#   'name': 'San Jose'},
#  {'coord': {'lon': -112.07, 'lat': 33.45},
#   'sys': {'country': 'US',
#    'timezone': -25200,
#    'sunrise': 1597063659,
#    'sunset': 1597112374},
#   'weather': [{'id': 711,
#     'main': 'Smoke',
#     'description': 'smoke',
#     'icon': '50d'}],
#   'main': {'temp': 40.78,
#    'feels_like': 35.48,
#    'temp_min': 39.44,
#    'temp_max': 42.22,
#    'pressure': 1007,
#    'humidity': 9},
#   'visibility': 10000,
#   'wind': {'speed': 5.1, 'deg': 260},
#   'clouds': {'all': 20},
#   'dt': 1597112133,
#   'id': 5308655,
#   'name': 'Phoenix'},
#  {'coord': {'lon': -74.08, 'lat': 40.73},
#   'sys': {'country': 'US',
#    'timezone': -14400,
#    'sunrise': 1597053733,
#    'sunset': 1597104066},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'main': {'temp': 28.36,
#    'feels_like': 31.43,
#    'temp_min': 25.56,
#    'temp_max': 30,
#    'pressure': 1015,
#    'humidity': 70},
#   'visibility': 10000,
#   'wind': {'speed': 2.6, 'deg': 210},
#   'clouds': {'all': 20},
#   'dt': 1597112122,
#   'id': 5099836,
#   'name': 'Jersey City'},
#  {'coord': {'lon': -111.91, 'lat': 33.41},
#   'sys': {'country': 'US',
#    'timezone': -25200,
#    'sunrise': 1597063624,
#    'sunset': 1597112332},
#   'weather': [{'id': 711,
#     'main': 'Smoke',
#     'description': 'smoke',
#     'icon': '50d'}],
#   'main': {'temp': 40.78,
#    'feels_like': 35.48,
#    'temp_min': 40,
#    'temp_max': 42,
#    'pressure': 1007,
#    'humidity': 9},
#   'visibility': 10000,
#   'wind': {'speed': 5.1, 'deg': 260},
#   'clouds': {'all': 20},
#   'dt': 1597112133,
#   'id': 5317058,
#   'name': 'Tempe'},
#  {'coord': {'lon': -122.33, 'lat': 47.61},
#   'sys': {'country': 'US',
#    'timezone': -25200,
#    'sunrise': 1597064362,
#    'sunset': 1597116595},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'main': {'temp': 23.87,
#    'feels_like': 21.69,
#    'temp_min': 21.67,
#    'temp_max': 26,
#    'pressure': 1015,
#    'humidity': 41},
#   'visibility': 10000,
#   'wind': {'speed': 3.1, 'deg': 320},
#   'clouds': {'all': 1},
#   'dt': 1597112144,
#   'id': 5809844,
#   'name': 'Seattle'},
#  {'coord': {'lon': -83, 'lat': 39.96},
#   'sys': {'country': 'US',
#    'timezone': -14400,
#    'sunrise': 1597055969,
#    'sunset': 1597106112},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'main': {'temp': 25.94,
#    'feels_like': 27.37,
#    'temp_min': 24.44,
#    'temp_max': 27.22,
#    'pressure': 1015,
#    'humidity': 69},
#   'visibility': 10000,
#   'wind': {'speed': 3.1, 'deg': 230},
#   'clouds': {'all': 20},
#   'dt': 1597112096,
#   'id': 4509177,
#   'name': 'Columbus'},
#  {'coord': {'lon': -96.95, 'lat': 32.81},
#   'sys': {'country': 'US',
#    'timezone': -18000,
#    'sunrise': 1597060091,
#    'sunset': 1597108684},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'main': {'temp': 33.37,
#    'feels_like': 33.41,
#    'temp_min': 32.78,
#    'temp_max': 34,
#    'pressure': 1012,
#    'humidity': 43},
#   'visibility': 10000,
#   'wind': {'speed': 4.6, 'deg': 160},
#   'clouds': {'all': 20},
#   'dt': 1597112110,
#   'id': 4700168,
#   'name': 'Irving'},
#  {'coord': {'lon': -96.7, 'lat': 33.02},
#   'sys': {'country': 'US',
#    'timezone': -18000,
#    'sunrise': 1597060011,
#    'sunset': 1597108645},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'main': {'temp': 32.87,
#    'feels_like': 30.44,
#    'temp_min': 31.67,
#    'temp_max': 34,
#    'pressure': 1013,
#    'humidity': 36},
#   'visibility': 10000,
#   'wind': {'speed': 6.2, 'deg': 180},
#   'clouds': {'all': 5},
#   'dt': 1597112110,
#   'id': 4719457,
#   'name': 'Plano'}]

# %%
#
weather = response.json()['list']
df1 = json_normalize(weather)
# Out:
# C:\Users\Matt\anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# run second list of city codes
url="https://api.openweathermap.org/data/2.5/group?id=5780993,5393015,5345860,4160021,4776222,5392423,5331835,4259418,4691930,5400075,5375480,5313457,5380748,5110302,5341145,4762894,5367929,5386834,5372223,5378538&appid=3a9fa2731241e7ab03bbf05564b12ba4&units=metric"

# %%
response = requests.get(url)
response.json()
# Out:
# {'cnt': 20,
#  'list': [{'coord': {'lon': -111.89, 'lat': 40.76},
#    'sys': {'country': 'US',
#     'timezone': -21600,
#     'sunrise': 1597062810,
#     'sunset': 1597113136},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'main': {'temp': 29.42,
#     'feels_like': 24.57,
#     'temp_min': 27.22,
#     'temp_max': 32,
#     'pressure': 1014,
#     'humidity': 15},
#    'visibility': 10000,
#    'wind': {'speed': 4.1, 'deg': 360},
#    'clouds': {'all': 40},
#    'dt': 1597112143,
#    'id': 5780993,
#    'name': 'Salt Lake City'},
#   {'coord': {'lon': -121.96, 'lat': 37.35},
#    'sys': {'country': 'US',
#     'timezone': -25200,
#     'sunrise': 1597065625,
#     'sunset': 1597115154},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'main': {'temp': 22.93,
#     'feels_like': 19.47,
#     'temp_min': 21.11,
#     'temp_max': 25,
#     'pressure': 1011,
#     'humidity': 53},
#    'visibility': 10000,
#    'wind': {'speed': 6.2, 'deg': 320},
#    'clouds': {'all': 20},
#    'dt': 1597112136,
#    'id': 5393015,
#    'name': 'Santa Clara'},
#   {'coord': {'lon': -118.42, 'lat': 33.92},
#    'sys': {'country': 'US',
#     'timezone': -25200,
#     'sunrise': 1597065137,
#     'sunset': 1597113944},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'main': {'temp': 18.59,
#     'feels_like': 14.98,
#     'temp_min': 17.22,
#     'temp_max': 20.56,
#     'pressure': 1013,
#     'humidity': 72},
#    'visibility': 10000,
#    'wind': {'speed': 6.7, 'deg': 260},
#    'clouds': {'all': 20},
#    'dt': 1597112134,
#    'id': 5345860,
#    'name': 'El Segundo'},
#   {'coord': {'lon': -81.66, 'lat': 30.33},
#    'sys': {'country': 'US',
#     'timezone': -14400,
#     'sunrise': 1597056656,
#     'sunset': 1597104781},
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10n'},
#     {'id': 211,
#      'main': 'Thunderstorm',
#      'description': 'thunderstorm',
#      'icon': '11n'}],
#    'main': {'temp': 23.59,
#     'feels_like': 25.5,
#     'temp_min': 23,
#     'temp_max': 24,
#     'pressure': 1019,
#     'humidity': 88},
#    'visibility': 10000,
#    'wind': {'speed': 3.6, 'deg': 140},
#    'clouds': {'all': 75},
#    'dt': 1597112089,
#    'id': 4160021,
#    'name': 'Jacksonville'},
#   {'coord': {'lon': -76.29, 'lat': 36.85},
#    'sys': {'country': 'US',
#     'timezone': -14400,
#     'sunrise': 1597054713,
#     'sunset': 1597104147},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'main': {'temp': 25.73,
#     'feels_like': 28.73,
#     'temp_min': 23.33,
#     'temp_max': 28,
#     'pressure': 1016,
#     'humidity': 74},
#    'visibility': 10000,
#    'wind': {'speed': 1.5, 'deg': 190},
#    'clouds': {'all': 1},
#    'dt': 1597112112,
#    'id': 4776222,
#    'name': 'Norfolk'},
#   {'coord': {'lon': -122.33, 'lat': 37.56},
#    'sys': {'country': 'US',
#     'timezone': -25200,
#     'sunrise': 1597065691,
#     'sunset': 1597115266},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'main': {'temp': 20.38,
#     'feels_like': 17.05,
#     'temp_min': 15,
#     'temp_max': 24,
#     'pressure': 1012,
#     'humidity': 68},
#    'visibility': 10000,
#    'wind': {'speed': 6.7, 'deg': 320},
#    'clouds': {'all': 20},
#    'dt': 1597112136,
#    'id': 5392423,
#    'name': 'San Mateo'},
#   {'coord': {'lon': -118.31, 'lat': 34.18},
#    'sys': {'country': 'US',
#     'timezone': -25200,
#     'sunrise': 1597065084,
#     'sunset': 1597113944},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'main': {'temp': 24.02,
#     'feels_like': 20.84,
#     'temp_min': 19.44,
#     'temp_max': 28,
#     'pressure': 1012,
#     'humidity': 34},
#    'visibility': 10000,
#    'wind': {'speed': 3.6, 'deg': 130},
#    'clouds': {'all': 1},
#    'dt': 1597112134,
#    'id': 5331835,
#    'name': 'Burbank'},
#   {'coord': {'lon': -86.16, 'lat': 39.77},
#    'sys': {'country': 'US',
#     'timezone': -14400,
#     'sunrise': 1597056750,
#     'sunset': 1597106847},
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10n'}],
#    'main': {'temp': 20.63,
#     'feels_like': 21.85,
#     'temp_min': 20,
#     'temp_max': 21.11,
#     'pressure': 1016,
#     'humidity': 88},
#    'visibility': 10000,
#    'wind': {'speed': 2.6, 'deg': 160},
#    'clouds': {'all': 40},
#    'dt': 1597112093,
#    'id': 4259418,
#    'name': 'Indianapolis'},
#   {'coord': {'lon': -97.32, 'lat': 32.73},
#    'sys': {'country': 'US',
#     'timezone': -18000,
#     'sunrise': 1597060188,
#     'sunset': 1597108765},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'main': {'temp': 33.1,
#     'feels_like': 31.93,
#     'temp_min': 31,
#     'temp_max': 35,
#     'pressure': 1012,
#     'humidity': 41},
#    'visibility': 10000,
#    'wind': {'speed': 5.7, 'deg': 150},
#    'clouds': {'all': 1},
#    'dt': 1597112104,
#    'id': 4691930,
#    'name': 'Fort Worth'},
#   {'coord': {'lon': -122.04, 'lat': 37.37},
#    'sys': {'country': 'US',
#     'timezone': -25200,
#     'sunrise': 1597065642,
#     'sunset': 1597115175},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'main': {'temp': 22.78,
#     'feels_like': 19.28,
#     'temp_min': 21.11,
#     'temp_max': 25,
#     'pressure': 1011,
#     'humidity': 53},
#    'visibility': 10000,
#    'wind': {'speed': 6.2, 'deg': 320},
#    'clouds': {'all': 20},
#    'dt': 1597112136,
#    'id': 5400075,
#    'name': 'Sunnyvale'},
#   {'coord': {'lon': -122.08, 'lat': 37.39},
#    'sys': {'country': 'US',
#     'timezone': -25200,
#     'sunrise': 1597065650,
#     'sunset': 1597115187},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'main': {'temp': 22.62,
#     'feels_like': 19.07,
#     'temp_min': 21.11,
#     'temp_max': 24.44,
#     'pressure': 1011,
#     'humidity': 53},
#    'visibility': 10000,
#    'wind': {'speed': 6.2, 'deg': 320},
#    'clouds': {'all': 20},
#    'dt': 1597112134,
#    'id': 5375480,
#    'name': 'Mountain View'},
#   {'coord': {'lon': -111.9, 'lat': 33.51},
#    'sys': {'country': 'US',
#     'timezone': -25200,
#     'sunrise': 1597063612,
#     'sunset': 1597112339},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'main': {'temp': 40.76,
#     'feels_like': 37.46,
#     'temp_min': 40,
#     'temp_max': 42,
#     'pressure': 1009,
#     'humidity': 10},
#    'visibility': 10000,
#    'wind': {'speed': 2.6, 'deg': 270},
#    'clouds': {'all': 1},
#    'dt': 1597112133,
#    'id': 5313457,
#    'name': 'Scottsdale'},
#   {'coord': {'lon': -122.14, 'lat': 37.44},
#    'sys': {'country': 'US',
#     'timezone': -25200,
#     'sunrise': 1597065659,
#     'sunset': 1597115207},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'main': {'temp': 22.18,
#     'feels_like': 20.06,
#     'temp_min': 20.56,
#     'temp_max': 24,
#     'pressure': 1012,
#     'humidity': 50},
#    'visibility': 10000,
#    'wind': {'speed': 3.6, 'deg': 310},
#    'clouds': {'all': 5},
#    'dt': 1597112135,
#    'id': 5380748,
#    'name': 'Palo Alto'},
#   {'coord': {'lon': -73.95, 'lat': 40.65},
#    'sys': {'country': 'US',
#     'timezone': -14400,
#     'sunrise': 1597053712,
#     'sunset': 1597104025},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'main': {'temp': 27.49,
#     'feels_like': 30.12,
#     'temp_min': 25,
#     'temp_max': 29.44,
#     'pressure': 1015,
#     'humidity': 70},
#    'visibility': 10000,
#    'wind': {'speed': 2.6, 'deg': 210},
#    'clouds': {'all': 20},
#    'dt': 1597112125,
#    'id': 5110302,
#    'name': 'Brooklyn'},
#   {'coord': {'lon': -122.03, 'lat': 37.32},
#    'sys': {'country': 'US',
#     'timezone': -25200,
#     'sunrise': 1597065646,
#     'sunset': 1597115168},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'main': {'temp': 22.85,
#     'feels_like': 19.37,
#     'temp_min': 21.11,
#     'temp_max': 25,
#     'pressure': 1011,
#     'humidity': 53},
#    'visibility': 10000,
#    'wind': {'speed': 6.2, 'deg': 320},
#    'clouds': {'all': 20},
#    'dt': 1597112134,
#    'id': 5341145,
#    'name': 'Cupertino'},
#   {'coord': {'lon': -76.35, 'lat': 37.03},
#    'sys': {'country': 'US',
#     'timezone': -14400,
#     'sunrise': 1597054708,
#     'sunset': 1597104181},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'main': {'temp': 26.7,
#     'feels_like': 29.74,
#     'temp_min': 25.56,
#     'temp_max': 28,
#     'pressure': 1016,
#     'humidity': 83},
#    'visibility': 10000,
#    'wind': {'speed': 3.6, 'deg': 190},
#    'clouds': {'all': 1},
#    'dt': 1597112111,
#    'id': 4762894,
#    'name': 'Hampton'},
#   {'coord': {'lon': -118.19, 'lat': 33.77},
#    'sys': {'country': 'US',
#     'timezone': -25200,
#     'sunrise': 1597065097,
#     'sunset': 1597113874},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'main': {'temp': 20.46,
#     'feels_like': 17.22,
#     'temp_min': 17.22,
#     'temp_max': 23.89,
#     'pressure': 1012,
#     'humidity': 60},
#    'visibility': 10000,
#    'wind': {'speed': 5.7, 'deg': 300},
#    'clouds': {'all': 1},
#    'dt': 1597112134,
#    'id': 5367929,
#    'name': 'Long Beach'},
#   {'coord': {'lon': -122.24, 'lat': 37.49},
#    'sys': {'country': 'US',
#     'timezone': -25200,
#     'sunrise': 1597065677,
#     'sunset': 1597115237},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'main': {'temp': 21.71,
#     'feels_like': 19.46,
#     'temp_min': 19,
#     'temp_max': 24,
#     'pressure': 1012,
#     'humidity': 50},
#    'visibility': 10000,
#    'wind': {'speed': 3.6, 'deg': 310},
#    'clouds': {'all': 5},
#    'dt': 1597112136,
#    'id': 5386834,
#    'name': 'Redwood City'},
#   {'coord': {'lon': -122.18, 'lat': 37.45},
#    'sys': {'country': 'US',
#     'timezone': -25200,
#     'sunrise': 1597065667,
#     'sunset': 1597115218},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'main': {'temp': 21.89,
#     'feels_like': 19.16,
#     'temp_min': 20,
#     'temp_max': 24,
#     'pressure': 1012,
#     'humidity': 77},
#    'visibility': 10000,
#    'wind': {'speed': 7.7, 'deg': 350},
#    'clouds': {'all': 5},
#    'dt': 1597112134,
#    'id': 5372223,
#    'name': 'Menlo Park'},
#   {'coord': {'lon': -122.27, 'lat': 37.8},
#    'sys': {'country': 'US',
#     'timezone': -25200,
#     'sunrise': 1597065650,
#     'sunset': 1597115278},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'main': {'temp': 16.83,
#     'feels_like': 11.98,
#     'temp_min': 13.89,
#     'temp_max': 19.44,
#     'pressure': 1012,
#     'humidity': 72},
#    'visibility': 10000,
#    'wind': {'speed': 7.7, 'deg': 310},
#    'clouds': {'all': 20},
#    'dt': 1597112134,
#    'id': 5378538,
#    'name': 'Oakland'}]}

# %%
weather = response.json()['list']
df2= json_normalize(weather)
# Out:
# C:\Users\Matt\anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead

# %%
# run third list of 10 city codes
url="https://api.openweathermap.org/data/2.5/group?id=5368361,4684888,5808079,4499379,4722625,5416541,4890119,5350159,5123853,5393212,4671240&appid=3a9fa2731241e7ab03bbf05564b12ba4&units=metric"

# %%
response = requests.get(url)
response.json()
# Out:
# {'cnt': 11,
#  'list': [{'coord': {'lon': -118.24, 'lat': 34.05},
#    'sys': {'country': 'US',
#     'timezone': -25200,
#     'sunrise': 1597065080,
#     'sunset': 1597113914},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'main': {'temp': 21.97,
#     'feels_like': 20.73,
#     'temp_min': 17.78,
#     'temp_max': 26,
#     'pressure': 1012,
#     'humidity': 60},
#    'visibility': 10000,
#    'wind': {'speed': 3.5, 'deg': 236},
#    'clouds': {'all': 1},
#    'dt': 1597112134,
#    'id': 5368361,
#    'name': 'Los Angeles'},
#   {'coord': {'lon': -96.81, 'lat': 32.78},
#    'sys': {'country': 'US',
#     'timezone': -18000,
#     'sunrise': 1597060061,
#     'sunset': 1597108648},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'main': {'temp': 32.67,
#     'feels_like': 33.16,
#     'temp_min': 31.11,
#     'temp_max': 33.33,
#     'pressure': 1012,
#     'humidity': 41},
#    'visibility': 10000,
#    'wind': {'speed': 3.1, 'deg': 150},
#    'clouds': {'all': 0},
#    'dt': 1597112104,
#    'id': 4684888,
#    'name': 'Dallas'},
#   {'coord': {'lon': -122.12, 'lat': 47.67},
#    'sys': {'country': 'US',
#     'timezone': -25200,
#     'sunrise': 1597064302,
#     'sunset': 1597116554},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'main': {'temp': 23.57,
#     'feels_like': 22.8,
#     'temp_min': 22.22,
#     'temp_max': 25,
#     'pressure': 1013,
#     'humidity': 55},
#    'visibility': 10000,
#    'wind': {'speed': 2.9, 'deg': 352},
#    'clouds': {'all': 0},
#    'dt': 1597112144,
#    'id': 5808079,
#    'name': 'Redmond'},
#   {'coord': {'lon': -77.94, 'lat': 34.23},
#    'sys': {'country': 'US',
#     'timezone': -14400,
#     'sunrise': 1597055385,
#     'sunset': 1597104267},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'main': {'temp': 27.16,
#     'feels_like': 30.57,
#     'temp_min': 26.67,
#     'temp_max': 28,
#     'pressure': 1016,
#     'humidity': 78},
#    'visibility': 10000,
#    'wind': {'speed': 2.6, 'deg': 190},
#    'clouds': {'all': 20},
#    'dt': 1597112096,
#    'id': 4499379,
#    'name': 'Wilmington'},
#   {'coord': {'lon': -96.73, 'lat': 32.95},
#    'sys': {'country': 'US',
#     'timezone': -18000,
#     'sunrise': 1597060025,
#     'sunset': 1597108645},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'main': {'temp': 32.91,
#     'feels_like': 30.49,
#     'temp_min': 31.67,
#     'temp_max': 34,
#     'pressure': 1013,
#     'humidity': 36},
#    'visibility': 10000,
#    'wind': {'speed': 6.2, 'deg': 180},
#    'clouds': {'all': 5},
#    'dt': 1597112110,
#    'id': 4722625,
#    'name': 'Richardson'},
#   {'coord': {'lon': -104.88, 'lat': 39.58},
#    'sys': {'country': 'US',
#     'timezone': -21600,
#     'sunrise': 1597061269,
#     'sunset': 1597111313},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'main': {'temp': 25.98,
#     'feels_like': 23.69,
#     'temp_min': 24.44,
#     'temp_max': 28.33,
#     'pressure': 1034,
#     'humidity': 24},
#    'visibility': 10000,
#    'wind': {'speed': 1.34, 'deg': 193},
#    'clouds': {'all': 84},
#    'dt': 1597112137,
#    'id': 5416541,
#    'name': 'Centennial'},
#   {'coord': {'lon': -88.01, 'lat': 41.81},
#    'sys': {'country': 'US',
#     'timezone': -18000,
#     'sunrise': 1597056943,
#     'sunset': 1597107542},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'main': {'temp': 20.65,
#     'feels_like': 22.92,
#     'temp_min': 20,
#     'temp_max': 21.11,
#     'pressure': 1012,
#     'humidity': 90},
#    'visibility': 10000,
#    'wind': {'speed': 1.34, 'deg': 261},
#    'clouds': {'all': 100},
#    'dt': 1597112114,
#    'id': 4890119,
#    'name': 'Downers Grove'},
#   {'coord': {'lon': -122.27, 'lat': 37.56},
#    'sys': {'country': 'US',
#     'timezone': -25200,
#     'sunrise': 1597065677,
#     'sunset': 1597115252},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'main': {'temp': 21.27,
#     'feels_like': 18.91,
#     'temp_min': 19,
#     'temp_max': 24,
#     'pressure': 1012,
#     'humidity': 50},
#    'visibility': 10000,
#    'wind': {'speed': 3.6, 'deg': 310},
#    'clouds': {'all': 5},
#    'dt': 1597112134,
#    'id': 5350159,
#    'name': 'Foster City'},
#   {'coord': {'lon': -73.72, 'lat': 40.77},
#    'sys': {'country': 'US',
#     'timezone': -14400,
#     'sunrise': 1597053642,
#     'sunset': 1597103985},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'main': {'temp': 25.65,
#     'feels_like': 26.84,
#     'temp_min': 24.44,
#     'temp_max': 27.78,
#     'pressure': 1015,
#     'humidity': 88},
#    'visibility': 10000,
#    'wind': {'speed': 6.2, 'deg': 190},
#    'clouds': {'all': 20},
#    'dt': 1597112126,
#    'id': 5123853,
#    'name': 'Lake Success'},
#   {'coord': {'lon': -118.49, 'lat': 34.02},
#    'sys': {'country': 'US',
#     'timezone': -25200,
#     'sunrise': 1597065143,
#     'sunset': 1597113971},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'main': {'temp': 18.92,
#     'feels_like': 17.94,
#     'temp_min': 17.78,
#     'temp_max': 21.67,
#     'pressure': 1012,
#     'humidity': 77},
#    'visibility': 10000,
#    'wind': {'speed': 3.6, 'deg': 240},
#    'clouds': {'all': 1},
#    'dt': 1597112136,
#    'id': 5393212,
#    'name': 'Santa Monica'},
#   {'coord': {'lon': -97.11, 'lat': 32.74},
#    'sys': {'country': 'US',
#     'timezone': -18000,
#     'sunrise': 1597060137,
#     'sunset': 1597108716},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'main': {'temp': 33.42,
#     'feels_like': 32.66,
#     'temp_min': 32.78,
#     'temp_max': 34.44,
#     'pressure': 1013,
#     'humidity': 34},
#    'visibility': 10000,
#    'wind': {'speed': 3.6, 'deg': 150},
#    'clouds': {'all': 5},
#    'dt': 1597112104,
#    'id': 4671240,
#    'name': 'Arlington'}]}

# %%
weather = response.json()['list']
df3 = json_normalize(weather)
# Out:
# C:\Users\Matt\anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead

# %%
# Concatenate DataFrames
df4 = [df1, df2, df3]
result = pd.concat(df4)

# %%
# clean up dataframe
# drop columns
result = result.drop(['weather', 'visibility', 'dt', 'id', 'coord.lon', 'coord.lat', 'sys.country', 'sys.timezone', 'sys.sunrise', 'sys.sunset'], axis=1)

# reset index
result.reset_index(drop=True, inplace=True)

result
# Out:
#               name  main.temp  main.feels_like  main.temp_min  main.temp_max  \
# 0         Glendale      40.87            35.93          39.44          42.22
# 1          Chicago      22.01            21.67          21.11          22.78
# 2    San Francisco      16.11            11.52          13.89          19.00
# 3           Austin      32.04            32.50          31.11          33.00
# 4        Charlotte      24.19            26.96          23.33          24.44
# 5          Houston      30.03            32.80          29.00          31.11
# 6      Lake Dallas      33.10            33.03          32.00          33.89
# 7        San Diego      30.01            30.33          29.00          31.00
# 8     Philadelphia      22.67            24.72          21.67          24.00
# 9           Denver      26.05            29.07          25.00          26.67
# 10     San Antonio      32.60            31.62          31.67          33.33
# 11        San Jose      23.08            19.66          21.11          25.00
# 12         Phoenix      40.78            35.48          39.44          42.22
# 13     Jersey City      28.36            31.43          25.56          30.00
# 14           Tempe      40.78            35.48          40.00          42.00
# 15         Seattle      23.87            21.69          21.67          26.00
# 16        Columbus      25.94            27.37          24.44          27.22
# 17          Irving      33.37            33.41          32.78          34.00
# 18           Plano      32.87            30.44          31.67          34.00
# 19  Salt Lake City      29.42            24.57          27.22          32.00
# 20     Santa Clara      22.93            19.47          21.11          25.00
# 21      El Segundo      18.59            14.98          17.22          20.56
# 22    Jacksonville      23.59            25.50          23.00          24.00
# 23         Norfolk      25.73            28.73          23.33          28.00
# 24       San Mateo      20.38            17.05          15.00          24.00
# 25         Burbank      24.02            20.84          19.44          28.00
# 26    Indianapolis      20.63            21.85          20.00          21.11
# 27      Fort Worth      33.10            31.93          31.00          35.00
# 28       Sunnyvale      22.78            19.28          21.11          25.00
# 29   Mountain View      22.62            19.07          21.11          24.44
# 30      Scottsdale      40.76            37.46          40.00          42.00
# 31       Palo Alto      22.18            20.06          20.56          24.00
# 32        Brooklyn      27.49            30.12          25.00          29.44
# 33       Cupertino      22.85            19.37          21.11          25.00
# 34         Hampton      26.70            29.74          25.56          28.00
# 35      Long Beach      20.46            17.22          17.22          23.89
# 36    Redwood City      21.71            19.46          19.00          24.00
# 37      Menlo Park      21.89            19.16          20.00          24.00
# 38         Oakland      16.83            11.98          13.89          19.44
# 39     Los Angeles      21.97            20.73          17.78          26.00
# 40          Dallas      32.67            33.16          31.11          33.33
# 41         Redmond      23.57            22.80          22.22          25.00
# 42      Wilmington      27.16            30.57          26.67          28.00
# 43      Richardson      32.91            30.49          31.67          34.00
# 44      Centennial      25.98            23.69          24.44          28.33
# 45   Downers Grove      20.65            22.92          20.00          21.11
# 46     Foster City      21.27            18.91          19.00          24.00
# 47    Lake Success      25.65            26.84          24.44          27.78
# 48    Santa Monica      18.92            17.94          17.78          21.67
# 49       Arlington      33.42            32.66          32.78          34.44
#
#     main.pressure  main.humidity  wind.speed  wind.deg  clouds.all
# 0            1009              9        4.60       280           1
# 1            1013             83        5.10       310          40
# 2            1012             68        6.70       320          20
# 3            1014             49        4.60       150           5
# 4            1016             83        2.10       200          20
# 5            1015             74        5.10       150           1
# 6            1012             43        4.60       150           1
# 7            1014             62        6.20       140           1
# 8            1014             83        2.10       190           1
# 9            1015             79        2.49       189           0
# 10           1013             52        7.70       150           1
# 11           1011             53        6.20       320          20
# 12           1007              9        5.10       260          20
# 13           1015             70        2.60       210          20
# 14           1007              9        5.10       260          20
# 15           1015             41        3.10       320           1
# 16           1015             69        3.10       230          20
# 17           1012             43        4.60       160          20
# 18           1013             36        6.20       180           5
# 19           1014             15        4.10       360          40
# 20           1011             53        6.20       320          20
# 21           1013             72        6.70       260          20
# 22           1019             88        3.60       140          75
# 23           1016             74        1.50       190           1
# 24           1012             68        6.70       320          20
# 25           1012             34        3.60       130           1
# 26           1016             88        2.60       160          40
# 27           1012             41        5.70       150           1
# 28           1011             53        6.20       320          20
# 29           1011             53        6.20       320          20
# 30           1009             10        2.60       270           1
# 31           1012             50        3.60       310           5
# 32           1015             70        2.60       210          20
# 33           1011             53        6.20       320          20
# 34           1016             83        3.60       190           1
# 35           1012             60        5.70       300           1
# 36           1012             50        3.60       310           5
# 37           1012             77        7.70       350           5
# 38           1012             72        7.70       310          20
# 39           1012             60        3.50       236           1
# 40           1012             41        3.10       150           0
# 41           1013             55        2.90       352           0
# 42           1016             78        2.60       190          20
# 43           1013             36        6.20       180           5
# 44           1034             24        1.34       193          84
# 45           1012             90        1.34       261         100
# 46           1012             50        3.60       310           5
# 47           1015             88        6.20       190          20
# 48           1012             77        3.60       240           1
# 49           1013             34        3.60       150           5

# %%
top50city_df

# %%
# join dataframes to add location
final_table = result.merge(top50city_df,how='right', left_on='name', right_on='City')

#gd_t50_df = gd_df.merge(t50_df,how='right', left_on='Location', right_on='Location')

# %% [raw]
# print(final_table)

# %%
# export to csv 

outname = 'weatherfinal.csv'

outdir = './output_data'
if not os.path.exists(outdir):
    os.mkdir(outdir)

fullname = os.path.join(outdir, outname)    

result.to_csv(fullname)
