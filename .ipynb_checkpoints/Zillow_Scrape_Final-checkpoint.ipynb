# %%
from splinter import Browser
from bs4 import BeautifulSoup
from time import sleep 
import pandas as pd
import os

# %%
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
item_df = pd.DataFrame(columns = ["address", "price", 'info', 'city', 'state'])
print(item_df)
# Out:
# Empty DataFrame
# Columns: [address, price, info, city, state]
# Index: []

# %%
web_list = ['https://www.zillow.com/homes/New-York,-NY_rb/',
'https://www.zillow.com/homes/Chicago,-IL_rb/',
'https://www.zillow.com/homes/San-Francisco,-CA_rb/',
'https://www.zillow.com/homes/Austin,-TX_rb/',
'https://www.zillow.com/homes/Los-Angeles,-CA_rb/',
'https://www.zillow.com/homes/Charlotte,-NC_rb/',
'https://www.zillow.com/homes/Houston,-TX_rb/',
'https://www.zillow.com/homes/Dallas,-TX_rb/',
'https://www.zillow.com/homes/San-Diego,-CA_rb/',
'https://www.zillow.com/homes/Philadelphia,-PA_rb/',
'https://www.zillow.com/homes/Denver,-CO_rb/',
'https://www.zillow.com/homes/San-Antonio,-TX_rb/',
'https://www.zillow.com/homes/San-Jose,-CA_rb/',
'https://www.zillow.com/homes/Phoenix,-AZ_rb/',
'https://www.zillow.com/homes/Jersey-City,-NJ_rb/',
'https://www.zillow.com/homes/Tempe,-AZ_rb/',
'https://www.zillow.com/homes/Seattle,-WA_rb/',
'https://www.zillow.com/homes/Columbus,-OH_rb/',
'https://www.zillow.com/homes/Irving,-TX_rb/',
'https://www.zillow.com/homes/Plano,-TX_rb/',
'https://www.zillow.com/homes/Salt-Lake-City,-UT_rb/',
'https://www.zillow.com/homes/Santa-Clara,-CA_rb/',
'https://www.zillow.com/homes/El-Segundo,-CA_rb/',
'https://www.zillow.com/homes/Jacksonville,-FL_rb/',
'https://www.zillow.com/homes/Norfolk,-VA_rb/',
'https://www.zillow.com/homes/San-Mateo,-CA_rb/',
'https://www.zillow.com/homes/Burbank,-CA_rb/',
'https://www.zillow.com/homes/Indianapolis,-IN_rb/',
'https://www.zillow.com/homes/Fort-Worth,-TX_rb/',
'https://www.zillow.com/homes/Sunnyvale,-CA_rb/',
'https://www.zillow.com/homes/Mountain-View,-CA_rb/',
'https://www.zillow.com/homes/Scottsdale,-AZ_rb/',
'https://www.zillow.com/homes/Palo-Alto,-CA_rb/',
'https://www.zillow.com/homes/Brooklyn,-NY_rb/',
'https://www.zillow.com/homes/Cupertino,-CA_rb/',
'https://www.zillow.com/homes/Hampton,-VA_rb/',
'https://www.zillow.com/homes/Long-Beach,-CA_rb/',
'https://www.zillow.com/homes/Redwood-City,-CA_rb/',
'https://www.zillow.com/homes/Menlo-Park,-CA_rb/',
'https://www.zillow.com/homes/Oakland,-CA_rb/',
'https://www.zillow.com/homes/Redmond,-WA_rb/',
'https://www.zillow.com/homes/Wilmington,-DE_rb/',
'https://www.zillow.com/homes/Richardson,-TX_rb/',
'https://www.zillow.com/homes/Centennial,-CO_rb/',
'https://www.zillow.com/homes/Downers-Grove,-IL_rb/',
'https://www.zillow.com/homes/Foster-City,-CA_rb/',
'https://www.zillow.com/homes/Lake-Success,-NY_rb/',
'https://www.zillow.com/homes/Santa-Monica,-CA_rb/',
'https://www.zillow.com/homes/Arlington,-TX_rb/']

for item in web_list:
    print(item)
# Out:
# https://www.zillow.com/homes/New-York,-NY_rb/
# https://www.zillow.com/homes/Chicago,-IL_rb/
# https://www.zillow.com/homes/San-Francisco,-CA_rb/
# https://www.zillow.com/homes/Austin,-TX_rb/
# https://www.zillow.com/homes/Los-Angeles,-CA_rb/
# https://www.zillow.com/homes/Charlotte,-NC_rb/
# https://www.zillow.com/homes/Houston,-TX_rb/
# https://www.zillow.com/homes/Dallas,-TX_rb/
# https://www.zillow.com/homes/San-Diego,-CA_rb/
# https://www.zillow.com/homes/Philadelphia,-PA_rb/
# https://www.zillow.com/homes/Denver,-CO_rb/
# https://www.zillow.com/homes/San-Antonio,-TX_rb/
# https://www.zillow.com/homes/San-Jose,-CA_rb/
# https://www.zillow.com/homes/Phoenix,-AZ_rb/
# https://www.zillow.com/homes/Jersey-City,-NJ_rb/
# https://www.zillow.com/homes/Tempe,-AZ_rb/
# https://www.zillow.com/homes/Seattle,-WA_rb/
# https://www.zillow.com/homes/Columbus,-OH_rb/
# https://www.zillow.com/homes/Irving,-TX_rb/
# https://www.zillow.com/homes/Plano,-TX_rb/
# https://www.zillow.com/homes/Salt-Lake-City,-UT_rb/
# https://www.zillow.com/homes/Santa-Clara,-CA_rb/
# https://www.zillow.com/homes/El-Segundo,-CA_rb/
# https://www.zillow.com/homes/Jacksonville,-FL_rb/
# https://www.zillow.com/homes/Norfolk,-VA_rb/
# https://www.zillow.com/homes/San-Mateo,-CA_rb/
# https://www.zillow.com/homes/Burbank,-CA_rb/
# https://www.zillow.com/homes/Indianapolis,-IN_rb/
# https://www.zillow.com/homes/Fort-Worth,-TX_rb/
# https://www.zillow.com/homes/Sunnyvale,-CA_rb/
# https://www.zillow.com/homes/Mountain-View,-CA_rb/
# https://www.zillow.com/homes/Scottsdale,-AZ_rb/
# https://www.zillow.com/homes/Palo-Alto,-CA_rb/
# https://www.zillow.com/homes/Brooklyn,-NY_rb/
# https://www.zillow.com/homes/Cupertino,-CA_rb/
# https://www.zillow.com/homes/Hampton,-VA_rb/
# https://www.zillow.com/homes/Long-Beach,-CA_rb/
# https://www.zillow.com/homes/Redwood-City,-CA_rb/
# https://www.zillow.com/homes/Menlo-Park,-CA_rb/
# https://www.zillow.com/homes/Oakland,-CA_rb/
# https://www.zillow.com/homes/Redmond,-WA_rb/
# https://www.zillow.com/homes/Wilmington,-DE_rb/
# https://www.zillow.com/homes/Richardson,-TX_rb/
# https://www.zillow.com/homes/Centennial,-CO_rb/
# https://www.zillow.com/homes/Downers-Grove,-IL_rb/
# https://www.zillow.com/homes/Foster-City,-CA_rb/
# https://www.zillow.com/homes/Lake-Success,-NY_rb/
# https://www.zillow.com/homes/Santa-Monica,-CA_rb/
# https://www.zillow.com/homes/Arlington,-TX_rb/

# %%
for x in range(0, 50):
    browser.visit(web_list[x])
    city = str(x)
    state = str(x)
    html = browser.html
    print("%"*29)
    print(type(html))
    soup = BeautifulSoup(html, 'html.parser')

    cardlist = soup.find_all('article', class_='list-card_not-saved')
    print("@"*17)
    print(type(cardlist))
    print(len(cardlist))

    for card in cardlist:
        address = card.find('address', class_='list-card-addr').text
        print("*************7the address is")
        print(address)
        info = card.find('ul', class_='list-card-details').text
        print("*************8the info is")
        print(info)
        try:
            price = card.find('div', class_='list-card-price').text

        except:
            print("no price")
            price = ""
        else:
            print("$++++++++++++++++++++9" +price)

        item_df = item_df.append(pd.DataFrame({'address': [address], 'price': [price], 'info': [info], 'city': [city], 'state': [state]}))
    sleep(5)
# Out:
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# <class 'str'>
# @@@@@@@@@@@@@@@@@
# <class 'bs4.element.ResultSet'>
# 40
# *************7the address is
# 802 Freeman St, Bronx, NY 10459
# *************8the info is
# 7 bds2 ba1,800 sqft
# $++++++++++++++++++++9$769,999
# *************7the address is
# 215 Hart Blvd APT 2F, Staten Island, NY 10301
# *************8the info is
# 1 bd1 ba773 sqft
# $++++++++++++++++++++9$309,999
# *************7the address is
# 74-01 Cypress Hills St, Ridgewood, NY 11385
# *************8the info is
# 3 bds3 ba-- sqft
# $++++++++++++++++++++9$818,000
# *************7the address is
# 159-24 95th St, Howard Beach, NY 11414
# *************8the info is
# 4 bds3 ba-- sqft
# $++++++++++++++++++++9$1,499,999
# *************7the address is
# 83-40 Austin St #4C, Kew Gardens, NY 11415
# *************8the info is
# 1 bd1 ba-- sqft
# $++++++++++++++++++++9$319,000
# *************7the address is
# 27 Roosevelt Ave, Staten Island, NY 10314
# *************8the info is
# 3 bds2 ba1,050 sqft
# $++++++++++++++++++++9$679,000
# *************7the address is
# 1452 Leland Ave, Bronx, NY 10460
# *************8the info is
# 8 bds4 ba3,850 sqft
# $++++++++++++++++++++9$1,198,000
# *************7the address is
# 61-45 98th St #10B, Rego Park, NY 11374
# *************8the info is
# 1 bd1 ba700 sqft
# $++++++++++++++++++++9$299,000
# *************7the address is
# 10847 44th Ave, Corona, NY 11368
# *************8the info is
# 7 bds4 ba-- sqft
# $++++++++++++++++++++9$1,116,000
# *************7the address is
# 60-25 83rd Pl, Middle Village, NY 11379
# *************8the info is
# 3 bds2 ba1,472 sqft
# $++++++++++++++++++++9$969,000
# *************7the address is
# 10-24 166th St #2A, Whitestone, NY 11357
# *************8the info is
# 2 bds1 ba1,050 sqft
# $++++++++++++++++++++9$405,888
# *************7the address is
# 22424 Union Tpke APT 4M, Oakland Gardens, NY 11364
# *************8the info is
# 2 bds2 ba1,200 sqft
# $++++++++++++++++++++9$429,000
# *************7the address is
# 3224 Tibbett Ave, Bronx, NY 10463
# *************8the info is
# 3 bds3 ba1,900 sqft
# $++++++++++++++++++++9$895,000
# *************7the address is
# 362 Van Brunt St #1A, Brooklyn, NY 11231
# *************8the info is
# 1 bd1 ba-- sqft
# $++++++++++++++++++++9$795,000
# *************7the address is
# 166-25 Powells Cove Blvd #8A, Whitestone, NY 11357
# *************8the info is
# 3 bds2 ba1,800 sqft
# $++++++++++++++++++++9$848,888
# *************7the address is
# (undisclosed Address), Queens, NY 11435
# *************8the info is
# 3 bds4 ba1,440 sqft
# $++++++++++++++++++++9$889,000
# *************7the address is
# 45 Red Cedar Ln, Staten Island, NY 10309
# *************8the info is
# 6 bds5 ba3,000 sqft
# $++++++++++++++++++++9$689,000
# *************7the address is
# 97-35 92nd St, Ozone Park, NY 11416
# *************8the info is
# 5 bds3 ba2,500 sqft
# $++++++++++++++++++++9$849,000
# *************7the address is
# 223-34 112th Rd, Queens Village, NY 11429
# *************8the info is
# 4 bds2 ba-- sqft
# $++++++++++++++++++++9$610,000
# *************7the address is
# 7213 67th Pl, Glendale, NY 11385
# *************8the info is
# 7 bds3 ba3,300 sqft
# $++++++++++++++++++++9$910,000
# *************7the address is
# 24 Pennyfield Ave APT 2B, Bronx, NY 10465
# *************8the info is
# 2 bds1 ba800 sqft
# $++++++++++++++++++++9$359,900
# *************7the address is
# 157-52 10th Ave, Whitestone, NY 11357
# *************8the info is
# 5 bds4 ba-- sqft
# $++++++++++++++++++++9$1,150,000
# *************7the address is
# 110 W 86th St APT 6E, New York, NY 10024
# *************8the info is
# 1 bd1 ba766 sqft
# $++++++++++++++++++++9$899,000
# *************7the address is
# 9-16 127th St, College Pt, NY 11356
# *************8the info is
# 3 bds1 ba-- sqft
# $++++++++++++++++++++9$649,000
# *************7the address is
# 41-31 51st St #2L, Woodside, NY 11377
# *************8the info is
# 1 bd1 ba-- sqft
# $++++++++++++++++++++9$360,000
# *************7the address is
# 61-45 98th St, Rego Park, NY 11374
# *************8the info is
# 1 bd1 ba700 sqft
# $++++++++++++++++++++9$299,000
# *************7the address is
# 2260 Benson Ave APT 1A, Brooklyn, NY 11214
# *************8the info is
# 2 bds1 ba950 sqft
# $++++++++++++++++++++9$415,000
# *************7the address is
# 425 Prospect Pl APT 3K, Brooklyn, NY 11238
# *************8the info is
# 1 bd1 ba-- sqft
# $++++++++++++++++++++9$459,000
# *************7the address is
# 33 W 93rd St APT 2G, New York, NY 10025
# *************8the info is
# 2 bds1 ba900 sqft
# $++++++++++++++++++++9$995,000
# *************7the address is
# 102-21 63rd Rd #B66, Flushing, NY 11375
# *************8the info is
# 2 bds1 ba83,420 sqft
# $++++++++++++++++++++9$388,000
# *************7the address is
# 63-09 108th St #7P, Forest Hills, NY 11375
# *************8the info is
# 2 bds2 ba-- sqft
# $++++++++++++++++++++9$489,000
# *************7the address is
# 3131 Grand Concourse APT 9A, Bronx, NY 10468
# *************8the info is
# Studio1 ba500 sqft
# $++++++++++++++++++++9$99,000
# *************7the address is
# 182 Avenue S, Brooklyn, NY 11223
# *************8the info is
# Studio-- ba2,080 sqft
# $++++++++++++++++++++9$1,549,000
# *************7the address is
# 4617 Bedford Ave, Brooklyn, NY 11235
# *************8the info is
# Studio2 ba1,585 sqft
# $++++++++++++++++++++9$799,990
# *************7the address is
# 665 50th St, Brooklyn, NY 11220
# *************8the info is
# Studio3 ba2,080 sqft
# $++++++++++++++++++++9$1,380,000
# *************7the address is
# 1100 Grand Concourse APT 4H, Bronx, NY 10456
# *************8the info is
# 2 bds1 ba1,200 sqft
# $++++++++++++++++++++9$370,000
# *************7the address is
# 79 Gordon St, Staten Island, NY 10304
# *************8the info is
# 3 bds2 ba1,120 sqft
# $++++++++++++++++++++9$589,000
# *************7the address is
# 310 Lenox Rd APT 5D, Brooklyn, NY 11226
# *************8the info is
# 1 bd1 ba124,314 sqft
# $++++++++++++++++++++9$290,000
# *************7the address is
# 20 Waldorf Ct, Brooklyn, NY 11230
# *************8the info is
# 6 bds3 ba2,304 sqft
# $++++++++++++++++++++9$1,895,000
# *************7the address is
# 321 E 89th St APT 3D, New York, NY 10128
# *************8the info is
# 1 bd1 ba500 sqft
# $++++++++++++++++++++9$420,000
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# <class 'str'>
# @@@@@@@@@@@@@@@@@
# <class 'bs4.element.ResultSet'>
# 40
# *************7the address is
# 401 E Ontario St APT 4002, Chicago, IL 60611
# *************8the info is
# 3 bds2 ba1,850 sqft
# $++++++++++++++++++++9$785,000
# *************7the address is
# 1237 W Cottage Pl, Chicago, IL 60607
# *************8the info is
# 3 bds3 ba1,900 sqft
# $++++++++++++++++++++9$799,900
# *************7the address is
# 42 E Schiller St, Chicago, IL 60610
# *************8the info is
# 5 bds4 ba4,036 sqft
# $++++++++++++++++++++9$2,895,000
# *************7the address is
# 212 E Cullerton St APT 510, Chicago, IL 60616
# *************8the info is
# Studio1 ba954 sqft
# $++++++++++++++++++++9$189,000
# *************7the address is
# 4755 S Saint Lawrence Ave #1B, Chicago, IL 60615
# *************8the info is
# 2 bds2 ba1,200 sqft
# $++++++++++++++++++++9$185,000
# *************7the address is
# 7744 S Hermitage Ave, Chicago, IL 60620
# *************8the info is
# 4 bds2 ba-- sqft
# $++++++++++++++++++++9$85,000
# *************7the address is
# 2837 N Halsted St #3S, Chicago, IL 60657
# *************8the info is
# 3 bds2 ba1,647 sqft
# $++++++++++++++++++++9$734,900
# *************7the address is
# 3342 N Southport Ave APT 4, Chicago, IL 60657
# *************8the info is
# 2 bds2 ba1,418 sqft
# $++++++++++++++++++++9$669,500
# *************7the address is
# 1428 W Fargo Ave #B1, Chicago, IL 60626
# *************8the info is
# 2 bds2 ba1,200 sqft
# $++++++++++++++++++++9$169,900
# *************7the address is
# 2251 W Wabansia Ave #206, Chicago, IL 60647
# *************8the info is
# 2 bds2 ba1,400 sqft
# $++++++++++++++++++++9$539,900
# *************7the address is
# 8450 S Marquette Ave, Chicago, IL 60617
# *************8the info is
# 7 bds3 ba4,700 sqft
# $++++++++++++++++++++9$275,000
# *************7the address is
# 3117 N Kenmore Ave, Chicago, IL 60657
# *************8the info is
# 3,049 sqft lot
# $++++++++++++++++++++9$699,000
# *************7the address is
# 2116 N California Ave #1, Chicago, IL
# *************8the info is
# 5 bds4 ba4,000 sqft
# $++++++++++++++++++++9$899,000
# *************7the address is
# 944 N Howe St, Chicago, IL 60610
# *************8the info is
# 2 bds2 ba1,400 sqft
# $++++++++++++++++++++9$550,000
# *************7the address is
# 6000 N Cicero Ave APT 411, Chicago, IL 60646
# *************8the info is
# 2 bds2 ba1,450 sqft
# $++++++++++++++++++++9$329,900
# *************7the address is
# 2116 N California Ave #2, Chicago, IL
# *************8the info is
# 4 bds3 ba2,400 sqft
# $++++++++++++++++++++9$775,000
# *************7the address is
# 1430 N Astor St APT 11C, Chicago, IL 60610
# *************8the info is
# 3 bds2 ba1,600 sqft
# $++++++++++++++++++++9$535,000
# *************7the address is
# 2936 N Wisner Ave, Chicago, IL 60618
# *************8the info is
# 4 bds4 ba2,500 sqft
# $++++++++++++++++++++9$769,900
# *************7the address is
# 4028 N Troy St, Chicago, IL 60618
# *************8the info is
# 4 bds2 ba-- sqft
# $++++++++++++++++++++9$465,000
# *************7the address is
# 1514 N Elk Grove Ave, Chicago, IL 60622
# *************8the info is
# 6 bds5 ba-- sqft
# $++++++++++++++++++++9$975,000
# *************7the address is
# 5455 N Sheridan Rd APT 1911, Chicago, IL 60640
# *************8the info is
# 1 bd1 ba900 sqft
# $++++++++++++++++++++9$199,000
# *************7the address is
# 2702 N Greenview Ave, Chicago, IL 60614
# *************8the info is
# 3,049 sqft lot
# $++++++++++++++++++++9$700,000
# *************7the address is
# 8747 W Bryn Mawr Ave APT 706, Chicago, IL 60631
# *************8the info is
# 2 bds2 ba1,294 sqft
# $++++++++++++++++++++9$325,000
# *************7the address is
# 4740 W Waveland Ave, Chicago, IL 60641
# *************8the info is
# 3 bds3 ba1,789 sqft
# $++++++++++++++++++++9$299,900
# *************7the address is
# 3232 N Halsted St APT H412, Chicago, IL 60657
# *************8the info is
# 2 bds2 ba-- sqft
# $++++++++++++++++++++9$449,000
# *************7the address is
# 405 N Wabash Ave UNIT 1401, Chicago, IL 60611
# *************8the info is
# 1 bd1 ba725 sqft
# $++++++++++++++++++++9$259,000
# *************7the address is
# 1529 State St UNIT TH7, Chicago, IL 60605
# *************8the info is
# 3 bds3 ba-- sqft
# $++++++++++++++++++++9$439,000
# *************7the address is
# 1111 S State St APT 506, Chicago, IL 60605
# *************8the info is
# 1 bd1 ba900 sqft
# $++++++++++++++++++++9$285,000
# *************7the address is
# 1111 S Wabash Ave APT 801, Chicago, IL 60605
# *************8the info is
# 2 bds2 ba1,357 sqft
# $++++++++++++++++++++9$375,000
# *************7the address is
# 737 N Lockwood Ave, Chicago, IL 60644
# *************8the info is
# 3 bds3 ba2,800 sqft
# $++++++++++++++++++++9$189,900
# *************7the address is
# 540 N Lake Shore Dr APT 701, Chicago, IL 60611
# *************8the info is
# 1 bd1 ba1,030 sqft
# $++++++++++++++++++++9$479,000
# *************7the address is
# 5230 W Race Ave, Chicago, IL 60644
# *************8the info is
# 8 bds3 ba-- sqft
# $++++++++++++++++++++9$250,000
# *************7the address is
# 1946 S Sawyer Ave, Chicago, IL 60623
# *************8the info is
# 7 bds3 ba-- sqft
# $++++++++++++++++++++9$239,000
# *************7the address is
# 7831 S Ridgeland Ave, Chicago, IL 60649
# *************8the info is
# 4 bds2 ba1,050 sqft
# $++++++++++++++++++++9$235,000
# *************7the address is
# 1835 N Rutherford Ave, Chicago, IL 60707
# *************8the info is
# 3 bds1 ba1,531 sqft
# $++++++++++++++++++++9$315,000
# *************7the address is
# 2300 W Wabansia Ave APT 210, Chicago, IL 60647
# *************8the info is
# 2 bds2 ba1,200 sqft
# $++++++++++++++++++++9$415,000
# *************7the address is
# 4150 W 58th Pl, Chicago, IL 60629
# *************8the info is
# 3 bds1 ba940 sqft
# $++++++++++++++++++++9$149,900
# *************7the address is
# 1542 N Rockwell St #G, Chicago, IL 60622
# *************8the info is
# 2 bds1 ba850 sqft
# $++++++++++++++++++++9$225,000
# *************7the address is
# 1501 S Indiana Ave UNIT I, Chicago, IL 60605
# *************8the info is
# 3 bds3 ba2,200 sqft
# $++++++++++++++++++++9$575,000
# *************7the address is
# 3820 W 80th Pl, Chicago, IL 60652
# *************8the info is
# 5 bds3 ba909 sqft
# $++++++++++++++++++++9$240,000
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# <class 'str'>
# @@@@@@@@@@@@@@@@@
# <class 'bs4.element.ResultSet'>
# 40
# *************7the address is
# 12 Chattanooga St #A, San Francisco, CA 94114
# *************8the info is
# 4 bds3 ba2,179 sqft
# $++++++++++++++++++++9$2,495,000
# *************7the address is
# 3824 Scott St APT 1, San Francisco, CA 94123
# *************8the info is
# 1 bd1 ba965 sqft
# $++++++++++++++++++++9$995,000
# *************7the address is
# 1623-1633 California St, San Francisco, CA 94109
# *************8the info is
# Studio-- ba15,052 sqft
# $++++++++++++++++++++9$7,100,000
# *************7the address is
# 720 York St SUITE 102, San Francisco, CA 94110
# *************8the info is
# 1 bd1 ba1,454 sqft
# $++++++++++++++++++++9$1,395,000
# *************7the address is
# 2001 Mcallister St APT 319, San Francisco, CA 94118
# *************8the info is
# 1 bd1 ba642 sqft
# $++++++++++++++++++++9$749,000
# *************7the address is
# 900 Bush St APT 1102, San Francisco, CA 94109
# *************8the info is
# 1 bd1 ba657 sqft
# $++++++++++++++++++++9$735,000
# *************7the address is
# 306-314 Francisco St, San Francisco, CA 94133
# *************8the info is
# Studio-- ba3,744 sqft
# $++++++++++++++++++++9$3,600,000
# *************7the address is
# 2696 Sutter St, San Francisco, CA 94115
# *************8the info is
# 2 bds1.5 ba1,290 sqft
# $++++++++++++++++++++9$999,000
# *************7the address is
# 8 Ramona Ave, San Francisco, CA 94103
# *************8the info is
# 3 bds1 ba1,430 sqft
# $++++++++++++++++++++9$1,599,000
# *************7the address is
# 2230 Mason St #M201, San Francisco, CA 94133
# *************8the info is
# 2 bds2 ba1,071 sqft
# $++++++++++++++++++++9$1,180,000
# *************7the address is
# 360 Guerrero St APT 218, San Francisco, CA 94103
# *************8the info is
# Studio1 ba508 sqft
# $++++++++++++++++++++9$599,000
# *************7the address is
# 518 29th St, San Francisco, CA 94131
# *************8the info is
# 2 bds1 ba1,170 sqft
# $++++++++++++++++++++9$1,295,000
# *************7the address is
# 455 Scott St #3, San Francisco, CA 94117
# *************8the info is
# 3 bds2 ba1,852 sqft
# $++++++++++++++++++++9$1,749,000
# *************7the address is
# 1822 38th Ave, San Francisco, CA 94122
# *************8the info is
# 6 bds3 ba2,401 sqft
# $++++++++++++++++++++9$1,495,000
# *************7the address is
# 1B + Balcony Plan, Elevant
# *************8the info is
# 1 bd1 ba574 sqft
# $++++++++++++++++++++9$790,000+
# *************7the address is
# 910 Lawton St, San Francisco, CA 94122
# *************8the info is
# 3 bds2 ba2,100 sqft
# $++++++++++++++++++++9$2,299,000
# *************7the address is
# 715 Mount Vernon Ave, San Francisco, CA 94112
# *************8the info is
# 4 bds1 ba1,075 sqft
# $++++++++++++++++++++9$1,250,000
# *************7the address is
# 1330 Chestnut St, San Francisco, CA 94123
# *************8the info is
# 3 bds2.5 ba1,765 sqft
# $++++++++++++++++++++9$1,995,000
# *************7the address is
# 755 Florida St UNIT 2, San Francisco, CA 94110
# *************8the info is
# 1 bd1 ba623 sqft
# $++++++++++++++++++++9$699,000
# *************7the address is
# 601 Van Ness Ave APT 311, San Francisco, CA 94102
# *************8the info is
# 1 bd1 ba558 sqft
# $++++++++++++++++++++9$605,000
# *************7the address is
# Residence 510 Plan, One Steuart Lane
# *************8the info is
# 2 bds3 ba2,278 sqft
# $++++++++++++++++++++9$5,595,000+
# *************7the address is
# 260 King St UNIT 553, San Francisco, CA 94107
# *************8the info is
# 1 bd1 ba556 sqft
# $++++++++++++++++++++9$680,000
# *************7the address is
# 501 Crescent Way APT 5207, San Francisco, CA 94134
# *************8the info is
# 2 bds2 ba1,095 sqft
# $++++++++++++++++++++9$748,000
# *************7the address is
# 443 Chenery St, San Francisco, CA 94131
# *************8the info is
# 3 bds2 ba1,646 sqft
# $++++++++++++++++++++9$1,795,000
# *************7the address is
# 460 Arkansas St, San Francisco, CA 94107
# *************8the info is
# 4 bds3 ba2,150 sqft
# $++++++++++++++++++++9$2,199,999
# *************7the address is
# 1 Daniel Burnham Ct APT 724, San Francisco, CA 94109
# *************8the info is
# 2 bds2 ba1,131 sqft
# $++++++++++++++++++++9$999,000
# *************7the address is
# 43-45 Pond St, San Francisco, CA 94114
# *************8the info is
# 2 bds3 ba-- sqft
# $++++++++++++++++++++9$2,050,000
# *************7the address is
# 522-524 Steiner St, San Francisco, CA 94117
# *************8the info is
# 8 bds5 ba4,376 sqft
# $++++++++++++++++++++9$2,595,000
# *************7the address is
# 1479 Revere Ave #1481, San Francisco, CA 94124
# *************8the info is
# Studio-- ba-- sqft
# $++++++++++++++++++++9$1,100,000
# *************7the address is
# 1243 Quesada Ave, San Francisco, CA 94124
# *************8the info is
# 3 bds1 ba1,250 sqft
# $++++++++++++++++++++9$850,000
# *************7the address is
# 209 Prentiss St, San Francisco, CA 94110
# *************8the info is
# 3 bds2.5 ba-- sqft
# $++++++++++++++++++++9$1,975,000
# *************7the address is
# Address Not Disclosed, San Francisco, CA 94103
# *************8the info is
# Studio-- ba4,185 sqft
# $++++++++++++++++++++9$2,495,000
# *************7the address is
# 333 1st St UNIT 1602, San Francisco, CA 94105
# *************8the info is
# 1 bd1 ba713 sqft
# $++++++++++++++++++++9$949,000
# *************7the address is
# 1623 18th St, San Francisco, CA 94107
# *************8the info is
# 2 bds2 ba1,102 sqft
# $++++++++++++++++++++9$1,200,000
# *************7the address is
# 280 Spear Street #32D Plan, MIRA
# *************8the info is
# 2 bds2 ba1,100 sqft
# $++++++++++++++++++++9$1,995,000+
# *************7the address is
# 614 Hamilton St, San Francisco, CA 94134
# *************8the info is
# 3 bds2 ba1,036 sqft
# $++++++++++++++++++++9$1,195,000
# *************7the address is
# 5320 Diamond Heights Blvd APT 305K, San Francisco, CA 94131
# *************8the info is
# 1 bd1 ba657 sqft
# $++++++++++++++++++++9$700,000
# *************7the address is
# studio-S1 Plan, 2177 Third Street
# *************8the info is
# -- bds1 ba515 sqft
# $++++++++++++++++++++9$740,000+
# *************7the address is
# 950 Harrison St UNIT 101, San Francisco, CA 94107
# *************8the info is
# 3 bds2 ba1,642 sqft
# $++++++++++++++++++++9$1,395,000
# *************7the address is
# 1775 Oak St, San Francisco, CA 94117
# *************8the info is
# 2 bds1 ba1,707 sqft
# $++++++++++++++++++++9$1,300,000
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# <class 'str'>
# @@@@@@@@@@@@@@@@@
# <class 'bs4.element.ResultSet'>
# 40
# *************7the address is
# 8518 Cahill Dr APT 49, Austin, TX 78729
# *************8the info is
# 3 bds3 ba1,476 sqft
# $++++++++++++++++++++9$280,000
# *************7the address is
# 6418 Zadock Woods Dr, Austin, TX 78749
# *************8the info is
# 4 bds3 ba2,922 sqft
# $++++++++++++++++++++9$645,000
# *************7the address is
# 1900 Barton Springs Rd UNIT 5024, Austin, TX 78704
# *************8the info is
# 1 bd1 ba839 sqft
# $++++++++++++++++++++9$524,900
# *************7the address is
# 7513 Corrie Cv, Austin, TX 78749
# *************8the info is
# 3 bds2 ba1,690 sqft
# $++++++++++++++++++++9$399,999
# *************7the address is
# 802 S 1st St APT 216, Austin, TX 78704
# *************8the info is
# 1 bd1 ba575 sqft
# $++++++++++++++++++++9$264,900
# *************7the address is
# 4405 Lareina Dr, Austin, TX 78745
# *************8the info is
# 4 bds3 ba2,949 sqft
# $++++++++++++++++++++9$949,000
# *************7the address is
# 1707 E 17th St #1707, Austin, TX 78702
# *************8the info is
# 3 bds3 ba1,920 sqft
# $++++++++++++++++++++9$749,000
# *************7the address is
# 10808 Canfield Dr, Austin, TX 78739
# *************8the info is
# 4 bds3 ba3,495 sqft
# $++++++++++++++++++++9$712,500
# *************7the address is
# 3703 Balcones Dr, Austin, TX 78731
# *************8the info is
# 4 bds5 ba4,586 sqft
# $++++++++++++++++++++9$2,795,000
# *************7the address is
# 8400 Jamestown Dr APT 204, Austin, TX 78758
# *************8the info is
# 2 bds2 ba968 sqft
# $++++++++++++++++++++9$205,000
# *************7the address is
# 2009 Dexter St, Austin, TX 78704
# *************8the info is
# 3 bds2 ba2,847 sqft
# $++++++++++++++++++++9$1,349,000
# *************7the address is
# 12507 Palfrey Dr, Austin, TX 78727
# *************8the info is
# 4 bds4 ba2,932 sqft
# $++++++++++++++++++++9$649,000
# *************7the address is
# 514 Academy Dr, Austin, TX 78704
# *************8the info is
# 2 bds1 ba1,008 sqft
# $++++++++++++++++++++9$615,000
# *************7the address is
# 6708 Manchaca Rd UNIT 12, Austin, TX 78745
# *************8the info is
# 3 bds3 ba1,898 sqft
# $++++++++++++++++++++9$419,900
# *************7the address is
# 12317 Noel Bain Cv, Del Valle, TX 78617
# *************8the info is
# 4 bds3 ba2,489 sqft
# $++++++++++++++++++++9$275,000
# *************7the address is
# 2811 Wilcrest Dr, Austin, TX 78748
# *************8the info is
# 3 bds2 ba1,408 sqft
# $++++++++++++++++++++9$250,000
# *************7the address is
# 1637 Lakecliff Hills Ln, Austin, TX 78732
# *************8the info is
# 5 bds6 ba5,189 sqft
# $++++++++++++++++++++9$1,659,000
# *************7the address is
# B4-B Plan, Little Ford South Congress
# *************8the info is
# 2 bds2 ba1,321 sqft
# $++++++++++++++++++++9$468,800+
# *************7the address is
# Windyhill Plan, Bradshaw Crossing   Ridgepointe and Cottage Collection
# *************8the info is
# 3 bds3 ba1,834 sqft
# $++++++++++++++++++++9$288,990+
# *************7the address is
# 8413 Romney Rd, Austin, TX 78748
# *************8the info is
# 3 bds3 ba1,792 sqft
# $++++++++++++++++++++9$459,000
# *************7the address is
# The Irvine Plan, Tiermo
# *************8the info is
# 4 bds2 ba1,796 sqft
# $++++++++++++++++++++9$254,990+
# *************7the address is
# 501 West Ave #1602, Austin, TX 78701
# *************8the info is
# 1 bd2 ba846 sqft
# $++++++++++++++++++++9$675,000
# *************7the address is
# 8406 Beethoven Run Plan, Oak Crest
# *************8the info is
# 3 bds2 ba1,568 sqft
# $++++++++++++++++++++9$89,995+
# *************7the address is
# 1104 Marcy St #D, Austin, TX 78745
# *************8the info is
# 2 bds2 ba1,096 sqft
# $++++++++++++++++++++9$469,900
# *************7the address is
# 2103 Charlotte Estates Dr, Austin, TX 78744
# *************8the info is
# 4 bds2 ba1,611 sqft
# $++++++++++++++++++++9$280,000
# *************7the address is
# 1104 Marcy St #C, Austin, TX 78745
# *************8the info is
# 4 bds4 ba2,144 sqft
# $++++++++++++++++++++9$755,000
# *************7the address is
# 5801 Ann Jene Ct, Austin, TX 78744
# *************8the info is
# 3 bds2 ba1,752 sqft
# $++++++++++++++++++++9$289,900
# *************7the address is
# 2603 Rogge Ln, Austin, TX 78723
# *************8the info is
# 4 bds2 ba2,408 sqft
# $++++++++++++++++++++9$589,990
# *************7the address is
# 300 Bowie St APT 3303, Austin, TX 78703
# *************8the info is
# 2 bds2 ba1,061 sqft
# $++++++++++++++++++++9$760,000
# *************7the address is
# Pendleton Plan, Stoney Ridge
# *************8the info is
# 4 bds3 ba1,578 sqft
# $++++++++++++++++++++9$224,990+
# *************7the address is
# 10322 Wolftrap Dr, Austin, TX 78749
# *************8the info is
# 4 bds3 ba3,515 sqft
# $++++++++++++++++++++9$529,000
# *************7the address is
# 8005 Siringo Pass, Austin, TX 78749
# *************8the info is
# 3 bds3 ba2,328 sqft
# $++++++++++++++++++++9$465,000
# *************7the address is
# Plan 217 Plan, Parten: 75ft. lots
# *************8the info is
# 4 bds3 ba2,965 sqft
# $++++++++++++++++++++9$534,990+
# *************7the address is
# 4110 Ridgeline Trl, Austin, TX 78731
# *************8the info is
# 3 bds3 ba1,947 sqft
# $++++++++++++++++++++9$390,000
# *************7the address is
# Castleton A Plan, The Grove
# *************8the info is
# 3 bds4 ba2,856 sqft
# $++++++++++++++++++++9$1,125,000+
# *************7the address is
# B2-A Plan, Little Ford South Congress
# *************8the info is
# 2 bds2 ba1,111 sqft
# $++++++++++++++++++++9$418,800+
# *************7the address is
# (undisclosed Address), Austin, TX 78748
# *************8the info is
# 3 bds3 ba1,436 sqft
# $++++++++++++++++++++9$290,500
# *************7the address is
# 2013 West Loop, Austin, TX 78758
# *************8the info is
# Studio-- ba4,124 sqft
# $++++++++++++++++++++9$615,000
# *************7the address is
# 6024 Signal Point, Austin, TX 78724
# *************8the info is
# 3 bds2 ba1,320 sqft
# $++++++++++++++++++++9$229,000
# *************7the address is
# Opus Plan, Vistas of Austin
# *************8the info is
# 3 bds2 ba1,592 sqft
# $++++++++++++++++++++9$283,990+
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# <ipython-input-5-f17860cd66e0> in <module>
#       3     city = str(x)
#       4     state = str(x)
# ----> 5     html = browser.html
#       6     print("%"*29)
#       7     print(type(html))
#
# ~\anaconda3\lib\site-packages\splinter\driver\webdriver\__init__.py in html(self)
#     309     @property
#     310     def html(self):
# --> 311         return self.driver.page_source
#     312
#     313     @property
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in page_source(self)
#     677             driver.page_source
#     678         """
# --> 679         return self.execute(Command.GET_PAGE_SOURCE)['value']
#     680
#     681     def close(self):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=84.0.4147.105)
#   (Driver info: chromedriver=2.34.522940 (1a76f96f66e3ca7b8e57d503b4dd3bccfba87af1),platform=Windows NT 10.0.18363 x86_64)

# %%
# export to csv
outname = 'housing_case.csv'

outdir = './output_data'
if not os.path.exists(outdir):
    os.mkdir(outdir)

fullname = os.path.join(outdir, outname)    

item_df.to_csv(fullname)
