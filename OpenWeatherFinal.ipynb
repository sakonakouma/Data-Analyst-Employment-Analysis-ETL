# %%
# Dependencies and Setup
import json
from pandas.io.json import json_normalize
import pandas as pd
import numpy as np
import time
import csv
import re
import os
import configparser
import requests

# Import API key
from config import weather_key

# %%
# determine city codes

#"top50city.csv"

#url = "city.list.json"

#response = requests.get(url)
#response.json()

#response.json().keys()

#JSON response
#response.json()['list']

#city_code = response.json('city.list.json')#['list']
#df99 = json_normalize(city_code)
#df99
# have to break up to 3 lists

# %%
# run first list of 20 city codes
url="https://api.openweathermap.org/data/2.5/group?id=5039192,4887398,5391959,4671654,5344994,4460243,4699066,4704482,4726311,5131095,5186794,4726206,5392171,5308655,5099836,5317058,5809844,4509177,4700168,4719457&appid=" + weather_key + "&units=metric"

#url = "http://api.openweathermap.org/data/2.5/weather?appid=" + weather_key + "&q="

# %%
# Using this method to load
response = requests.get(url)
response.json()
# Out:
# {'cnt': 20,
#  'list': [{'coord': {'lon': -95.38, 'lat': 46.52},
#    'sys': {'country': 'US',
#     'timezone': -18000,
#     'sunrise': 1597058058,
#     'sunset': 1597109964},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'main': {'temp': 16.86,
#     'feels_like': 17,
#     'temp_min': 16,
#     'temp_max': 17.78,
#     'pressure': 1015,
#     'humidity': 82},
#    'visibility': 10000,
#    'wind': {'speed': 1.5, 'deg': 270},
#    'clouds': {'all': 1},
#    'dt': 1597068928,
#    'id': 5039192,
#    'name': 'New York Mills'},
#   {'coord': {'lon': -87.65, 'lat': 41.85},
#    'sys': {'country': 'US',
#     'timezone': -18000,
#     'sunrise': 1597056852,
#     'sunset': 1597107461},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'main': {'temp': 26.09,
#     'feels_like': 26.77,
#     'temp_min': 25.56,
#     'temp_max': 26.67,
# ...

# %%
#
response.json().keys()

#JSON response
response.json()['list']
# Out:
# [{'coord': {'lon': -95.38, 'lat': 46.52},
#   'sys': {'country': 'US',
#    'timezone': -18000,
#    'sunrise': 1597058058,
#    'sunset': 1597109964},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'main': {'temp': 16.86,
#    'feels_like': 17,
#    'temp_min': 16,
#    'temp_max': 17.78,
#    'pressure': 1015,
#    'humidity': 82},
#   'visibility': 10000,
#   'wind': {'speed': 1.5, 'deg': 270},
#   'clouds': {'all': 1},
#   'dt': 1597068928,
#   'id': 5039192,
#   'name': 'New York Mills'},
#  {'coord': {'lon': -87.65, 'lat': 41.85},
#   'sys': {'country': 'US',
#    'timezone': -18000,
#    'sunrise': 1597056852,
#    'sunset': 1597107461},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'main': {'temp': 26.09,
#    'feels_like': 26.77,
#    'temp_min': 25.56,
#    'temp_max': 26.67,
#    'pressure': 1014,
#    'humidity': 78},
# ...

# %%
#
weather = response.json()['list']
df1 = json_normalize(weather)
# Out:
# C:\Users\Matt\anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# run second list of city codes
url="https://api.openweathermap.org/data/2.5/group?id=5780993,5393015,5345860,4160021,4776222,5392423,5331835,4259418,4691930,5400075,5375480,5313457,5380748,5110302,5341145,4762894,5367929,5386834,5372223,5378538&appid=3a9fa2731241e7ab03bbf05564b12ba4&units=metric"

# %%
response = requests.get(url)
response.json()
# Out:
# {'cnt': 20,
#  'list': [{'coord': {'lon': -111.89, 'lat': 40.76},
#    'sys': {'country': 'US',
#     'timezone': -21600,
#     'sunrise': 1597062810,
#     'sunset': 1597113136},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'main': {'temp': 20.08,
#     'feels_like': 15.84,
#     'temp_min': 17.78,
#     'temp_max': 23,
#     'pressure': 1019,
#     'humidity': 25},
#    'visibility': 10000,
#    'wind': {'speed': 3.1, 'deg': 100},
#    'clouds': {'all': 75},
#    'dt': 1597068950,
#    'id': 5780993,
#    'name': 'Salt Lake City'},
#   {'coord': {'lon': -121.96, 'lat': 37.35},
#    'sys': {'country': 'US',
#     'timezone': -25200,
#     'sunrise': 1597065625,
#     'sunset': 1597115154},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'main': {'temp': 15.95,
#     'feels_like': 15.79,
#     'temp_min': 15,
#     'temp_max': 17,
# ...

# %%
weather = response.json()['list']
df2= json_normalize(weather)
# Out:
# C:\Users\Matt\anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead

# %%
# run third list of 10 city codes
url="https://api.openweathermap.org/data/2.5/group?id=5808079,4499379,4722625,5416541,4890119,5350159,5123853,5393212,4671240&appid=3a9fa2731241e7ab03bbf05564b12ba4&units=metric"

# %%
response = requests.get(url)
response.json()
# Out:
# {'cnt': 9,
#  'list': [{'coord': {'lon': -122.12, 'lat': 47.67},
#    'sys': {'country': 'US',
#     'timezone': -25200,
#     'sunrise': 1597064302,
#     'sunset': 1597116554},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'main': {'temp': 13.16,
#     'feels_like': 13.23,
#     'temp_min': 10.56,
#     'temp_max': 16.11,
#     'pressure': 1019,
#     'humidity': 91},
#    'visibility': 10000,
#    'wind': {'speed': 0.66, 'deg': 15},
#    'clouds': {'all': 0},
#    'dt': 1597068954,
#    'id': 5808079,
#    'name': 'Redmond'},
#   {'coord': {'lon': -77.94, 'lat': 34.23},
#    'sys': {'country': 'US',
#     'timezone': -14400,
#     'sunrise': 1597055385,
#     'sunset': 1597104267},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'main': {'temp': 28.49,
#     'feels_like': 31.79,
#     'temp_min': 27.78,
#     'temp_max': 29.44,
# ...

# %%
weather = response.json()['list']
df3 = json_normalize(weather)
# Out:
# C:\Users\Matt\anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead

# %%
# Concatenate DataFrames
df4 = [df1, df2, df3]
result = pd.concat(df4)

# %%
# clean up dataframe
# drop columns
result = result.drop(['weather', 'visibility', 'dt', 'id', 'coord.lon', 'coord.lat', 'sys.country', 'sys.timezone', 'sys.sunrise', 'sys.sunset'], axis=1)

# %%
# export to csv 
result.to_csv ('weatherfinal.csv', index = False, header=True)
