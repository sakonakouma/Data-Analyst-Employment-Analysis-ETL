# %%
from splinter import Browser
from bs4 import BeautifulSoup
from time import sleep 
import pandas as pd

# %%
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
url = 'https://www.zillow.com/homes/San-Francisco,-CA_rb/?searchQueryState=%7B%22pagination%22%3A%7B%7D%2C%22usersSearchTerm%22%3A%22San%20Francisco%2C%20CA%22%2C%22mapBounds%22%3A%7B%22west%22%3A-122.55699386014798%2C%22east%22%3A-122.30966413985202%2C%22south%22%3A37.69011402348307%2C%22north%22%3A37.86037086200889%7D%2C%22regionSelection%22%3A%5B%7B%22regionId%22%3A20330%2C%22regionType%22%3A6%7D%5D%2C%22mapZoom%22%3A12%2C%22filterState%22%3A%7B%22pmf%22%3A%7B%22value%22%3Afalse%7D%2C%22fore%22%3A%7B%22value%22%3Afalse%7D%2C%22auc%22%3A%7B%22value%22%3Afalse%7D%2C%22nc%22%3A%7B%22value%22%3Afalse%7D%2C%22fr%22%3A%7B%22value%22%3Atrue%7D%2C%22fsbo%22%3A%7B%22value%22%3Afalse%7D%2C%22cmsn%22%3A%7B%22value%22%3Afalse%7D%2C%22pf%22%3A%7B%22value%22%3Afalse%7D%2C%22fsba%22%3A%7B%22value%22%3Afalse%7D%7D%2C%22isListVisible%22%3Atrue%2C%22isMapVisible%22%3Afalse%7D'
browser.visit(url)

# %%
item_df = pd.DataFrame(columns = ["address", "price", 'info', 'city', 'state'])
print(item_df)
# Out:
# Empty DataFrame
# Columns: [address, price, info, city, state]
# Index: []

# %%
# for x in range(1, 20):
#     sleep(2)

#     html = browser.html
#     soup = BeautifulSoup(html, 'html.parser')

#     quotes = soup.find_all('address', class_='list-card-addr')

#     for quote in quotes:
#         print('page:', x, '-------------')
#         print(quote.text)

#     browser.click_link_by_partial_text('Chevron Right')

# %%
# class ZrentItem(object):
#     def __init__(address, price, info, state):
#         self.address = address
#         self.price = price
#         self.info = info
#         self.state = state

# %%
city = "San Francisco"
state = "CA"

# %%
for iterrows - t50_df 
    create url like  https://www.zillow.com/homes/San-Francisco,-CA_rb/  use city and state column
    go to browser url
    indent below
    update city and state below
    may have to split up list and add note in code
    may do incognito
    

for x in range(1, 2):
    sleep(2)

    html = browser.html
    print("%"*29)
    print(type(html))
    soup = BeautifulSoup(html, 'html.parser')

    cardlist = soup.find_all('article', class_='list-card_not-saved')
    print("@"*17)
    print(type(cardlist))
    print(len(cardlist))

    for card in cardlist:
        address = card.find('address', class_='list-card-addr').text
        print("*************7the address is")
        print(address)
        info = card.find('ul', class_='list-card-details').text
        print("*************8the info is")
        print(info)
        try:
            price = card.find('div', class_='list-card-price').text
            
        except:
            print("no price")
            price = ""
        else:
            print("$+" +price)
        
        item_df = item_df.append(pd.DataFrame({'address': [address], 'price': [price], 'info': [info], 'city': [city], 'state': [state]}))
    sleep(5)
    browser.click_link_by_partial_text('Chevron Right')

#     for quote in quotes:
#         address = 
#         print('page:', x, '-------------')
#         print(quote.text)
# Out:
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# <class 'str'>
# @@@@@@@@@@@@@@@@@
# <class 'bs4.element.ResultSet'>
# 40
# *************7the address is
# 49 Zoe St APT 14, San Francisco, CA 94107
# *************8the info is
# 1 bd1.5 ba987 sqft
# $+$3,500/mo
# *************7the address is
# Alchemy | 200 Buchanan St, San Francisco, CA
# *************8the info is
# $2,775+ Studio$3,165+ 1 bd$4,855+ 2 bds$7,185 3 bds
# no price
# *************7the address is
# 1190 Mission at Trinity Place | 1190 Mission St, San Francisco, CA
# *************8the info is
# $2,099+ Studio$2,299+ 1 bd$2,599+ 2 bds
# no price
# *************7the address is
# 399 Fremont | 399 Fremont St, San Francisco, CA
# *************8the info is
# $2,325+ Studio$3,326+ 1 bd$3,896+ 2 bds$13,483 3 bds
# no price
# *************7the address is
# Avalon Hayes Valley | 325 Octavia St, San Francisco, CA
# *************8the info is
# $2,420+ Studio$3,105+ 1 bd$3,980+ 2 bds
# no price
# *************7the address is
# 435 Tehama St APT 2, San Francisco, CA 94103
# *************8the info is
# 2 bds1 ba700 sqft
# $+$2,895/mo
# *************7the address is
# 650 Chestnut St APT 109, San Francisco, CA 94133
# *************8the info is
# 2 bds2 ba1,027 sqft
# $+$4,200/mo
# *************7the address is
# 1788 Clay St APT 404, San Francisco, CA 94109
# *************8the info is
# 2 bds2 ba915 sqft
# $+$5,000/mo
# *************7the address is
# 758A 7th Ave #A, San Francisco, CA 94118
# *************8the info is
# 1 bd1 ba930 sqft
# $+$3,830/mo
# *************7the address is
# 325 Berry St, San Francisco, CA
# *************8the info is
# $4,800+ 2 bds
# no price
# *************7the address is
# 651 10th Ave APT 2, San Francisco, CA 94118
# *************8the info is
# 2 bds1.5 ba-- sqft
# $+$3,000/mo
# *************7the address is
# Landing Furnished Apartments in SF: Monthly Leases, $0 Deposit | 1320 4th St, San Francisco, CA
# *************8the info is
# $2,910+ Studio$2,999+ 1 bd$3,839+ 2 bds$5,922 3 bds
# no price
# *************7the address is
# The Rise Hayes Valley | 1699 Market St, San Francisco, CA
# *************8the info is
# $2,665+ Studio$3,195+ 1 bd$3,915+ 2 bds
# no price
# *************7the address is
# 75 Lily St APT 2, San Francisco, CA 94102
# *************8the info is
# 1 bd1 ba672 sqft
# $+$3,500/mo
# *************7the address is
# eaves Diamond Heights | 5285 Diamond Heights Blvd, San Francisco, CA
# *************8the info is
# $2,552+ 1 bd$3,794+ 2 bds$4,998+ 3 bds
# no price
# *************7the address is
# Argenta | 1 Polk St, San Francisco, CA
# *************8the info is
# $3,440+ 1 bd$3,700+ 2 bds
# no price
# *************7the address is
# Olume | 1401 Mission St, San Francisco, CA
# *************8the info is
# $2,209+ Studio$2,753+ 1 bd$3,509+ 2 bds
# no price
# *************7the address is
# 848 N Point St FLOOR 2, San Francisco, CA 94109
# *************8the info is
# 2 bds2 ba1,350 sqft
# $+$4,450/mo
# *************7the address is
# 400 Beale St, San Francisco, CA
# *************8the info is
# $2,888+ 1 bd$4,200+ 2 bds
# no price
# *************7the address is
# The Madelon | 2823 18th St, San Francisco, CA
# *************8the info is
# $2,946+ Studio$2,986+ 1 bd$3,996+ 2 bds
# no price
# *************7the address is
# 1019 Guerrero St, San Francisco, CA 94110
# *************8the info is
# 3 bds1.5 ba1,350 sqft
# $+$5,000/mo
# *************7the address is
# 1674 Filbert St APT 4, San Francisco, CA 94123
# *************8the info is
# 3 bds1 ba1,100 sqft
# $+$5,100/mo
# *************7the address is
# Landing: Designer Furnished, Monthly Leases, Prime Locations in San Francisco | 535 Mission St, San Francisco, CA
# *************8the info is
# $2,910+ Studio$2,999+ 1 bd$3,839+ 2 bds$5,922 3 bds
# no price
# *************7the address is
# AVA 55 Ninth | 55 9th St, San Francisco, CA
# *************8the info is
# $2,375+ Studio$2,841+ 1 bd$3,255+ 2 bds
# no price
# *************7the address is
# Venn On Market | 1844 Market St, San Francisco, CA
# *************8the info is
# $2,995+ 1 bd$4,685+ 2 bds$6,375 3 bds
# no price
# *************7the address is
# One Henry Adams | 1 Henry Adams St, San Francisco, CA
# *************8the info is
# $2,292+ Studio$2,796+ 1 bd$3,598+ 2 bds$5,503+ 3 bds
# no price
# *************7the address is
# Avalon Dogpatch | 800 Indiana St, San Francisco, CA
# *************8the info is
# $2,270+ Studio$2,790+ 1 bd$3,420+ 2 bds$5,975+ 3 bds
# no price
# *************7the address is
# Azure | 690 Long Bridge St, San Francisco, CA
# *************8the info is
# $2,893+ 1 bd$3,726+ 2 bds
# no price
# *************7the address is
# Towers at Rincon | 88 Howard St, San Francisco, CA
# *************8the info is
# $2,540+ Studio$2,650+ 1 bd$3,690+ 2 bds
# no price
# *************7the address is
# 77 Bluxome | 77 Bluxome St, San Francisco, CA
# *************8the info is
# $1,759+ Studio
# no price
# *************7the address is
# Etta | 1285 Sutter St, San Francisco, CA
# *************8the info is
# $2,657 Studio$2,908+ 1 bd$3,655+ 2 bds$5,161 3 bds
# no price
# *************7the address is
# Etta, F
# *************8the info is
# 1 bd1 ba706 sqft
# $+$2,960/mo
# *************7the address is
# Etta, H
# *************8the info is
# 1 bd1 ba598 sqft
# $+$2,752/mo
# *************7the address is
# 88 King St, San Francisco, CA
# *************8the info is
# $4,200+ 2 bds
# no price
# *************7the address is
# Lofts at One Powell | 10 Cyril Magnin St, San Francisco, CA
# *************8the info is
# $2,899+ Studio$2,800+ 1 bd$3,900+ 2 bds
# no price
# *************7the address is
# 2450 Lake St APT 5, San Francisco, CA 94121
# *************8the info is
# 2 bds1 ba800 sqft
# $+$3,400/mo
# *************7the address is
# Avalon Ocean Avenue | 1200 Ocean Ave, San Francisco, CA
# *************8the info is
# $2,262+ Studio$2,605+ 1 bd$3,235+ 2 bds
# no price
# *************7the address is
# Fifteen Fifty | 1550 Mission St, San Francisco, CA
# *************8the info is
# $2,950+ Studio$4,525+ 1 bd$5,500+ 2 bds$16,000 3 bds
# no price
# *************7the address is
# 201 Harrison St, San Francisco, CA
# *************8the info is
# $1,950+ Studio$2,799+ 1 bd$3,200+ 2 bds
# no price
# *************7the address is
# AVA Nob Hill | 965 Sutter St, San Francisco, CA
# *************8the info is
# $2,039+ Studio$2,380+ 1 bd$3,463+ 2 bds
# no price
# C:\Users\Matt\anaconda3\lib\site-packages\splinter\driver\webdriver\__init__.py:528: FutureWarning: browser.find_link_by_partial_text is deprecated. Use browser.links.find_by_partial_text instead.
#   FutureWarning,
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# <class 'str'>
# @@@@@@@@@@@@@@@@@
# <class 'bs4.element.ResultSet'>
# 40
# *************7the address is
# 940 York St, San Francisco, CA 94110
# *************8the info is
# 4 bds1.5 ba1,600 sqft
# $+$6,300/mo
# *************7the address is
# 318 Maple St, San Francisco, CA
# *************8the info is
# $4,200 2 bds$7,200 3 bds
# no price
# *************7the address is
# 201 Folsom Street Mixed-Use | 201 Folsom St, San Francisco, CA
# *************8the info is
# $2,995 Studio$3,000+ 1 bd$4,999+ 2 bds$11,000+ 3 bds
# no price
# *************7the address is
# 33 Tehama | 33 Tehama St, San Francisco, CA
# *************8the info is
# $2,814+ 1 bd$4,730+ 2 bds
# no price
# *************7the address is
# 1501 44th Ave, San Francisco, CA 94122
# *************8the info is
# 3 bds4 ba2,118 sqft
# $+$5,800/mo
# *************7the address is
# 2608 Sutter St, San Francisco, CA 94115
# *************8the info is
# 2 bds1 ba700 sqft
# $+$3,700/mo
# *************7the address is
# 653 Cayuga Ave, San Francisco, CA 94112
# *************8the info is
# 2 bds2 ba1,300 sqft
# $+$3,350/mo
# *************7the address is
# 1010 Anza St #301, San Francisco, CA 94118
# *************8the info is
# 2 bds1 ba800 sqft
# $+$2,995/mo
# *************7the address is
# 1084 Clay St APT 3, San Francisco, CA 94108
# *************8the info is
# 3 bds2 ba-- sqft
# $+$5,200/mo
# *************7the address is
# 2023 32nd Ave, San Francisco, CA 94116
# *************8the info is
# 3 bds1 ba815 sqft
# $+$3,900/mo
# *************7the address is
# 333 Fremont | 333 Fremont St, San Francisco, CA
# *************8the info is
# $2,735+ 1 bd$3,489+ 2 bds
# no price
# *************7the address is
# 760 6th Ave, San Francisco, CA
# *************8the info is
# $2,300+ 1 bd$3,200 2 bds
# no price
# *************7the address is
# 25 Grace St, San Francisco, CA 94103
# *************8the info is
# 1 bd1 ba-- sqft
# $+$3,000/mo
# *************7the address is
# 1030 York St, San Francisco, CA
# *************8the info is
# $5,300+ 4 bds
# no price
# *************7the address is
# 50 Paulding St #2, San Francisco, CA 94112
# *************8the info is
# 3 bds1 ba1,114 sqft
# $+$3,990/mo
# *************7the address is
# 199 New Montgomery Street Condominiums | 199 New Montgomery St, San Francisco, CA
# *************8the info is
# $2,600 Studio$2,995+ 1 bd$3,700+ 2 bds
# no price
# *************7the address is
# 300 3rd St, San Francisco, CA
# *************8the info is
# $2,400+ Studio$2,895+ 1 bd
# no price
# *************7the address is
# Strata at Mission Bay | 1201 4th St, San Francisco, CA
# *************8the info is
# $2,794+ 1 bd$3,976+ 2 bds
# no price
# *************7the address is
# Venue | 1155 4th St, San Francisco, CA
# *************8the info is
# $2,657+ Studio$3,228+ 1 bd$3,994+ 2 bds
# no price
# *************7the address is
# 433 Dolores St, San Francisco, CA 94110
# *************8the info is
# 3 bds1 ba1,750 sqft
# $+$5,800/mo
# *************7the address is
# 325 Day St, San Francisco, CA 94131
# *************8the info is
# 2 bds1.5 ba1,106 sqft
# $+$4,250/mo
# *************7the address is
# Ashton San Francisco Apartments | 301 Executive Park Blvd, San Francisco, CA
# *************8the info is
# $2,957 Studio$2,683+ 1 bd$3,694+ 2 bds
# no price
# *************7the address is
# 328 5th Ave #2, San Francisco, CA 94118
# *************8the info is
# 2 bds1 ba820 sqft
# $+$2,975/mo
# *************7the address is
# Vara | 1600 15th St, San Francisco, CA
# *************8the info is
# $2,357+ Studio$2,585+ 1 bd$3,322+ 2 bds$4,996+ 3 bds
# no price
# *************7the address is
# 2600 18th St SUITE 24, San Francisco, CA 94110
# *************8the info is
# 2 bds2 ba1,550 sqft
# $+$4,600/mo
# *************7the address is
# 1025 Hyde St, San Francisco, CA
# *************8the info is
# $2,725+ 1 bd
# no price
# *************7the address is
# Potrero Launch | 2235 3rd St, San Francisco, CA
# *************8the info is
# $2,293+ Studio$2,658+ 1 bd$3,821+ 2 bds
# no price
# *************7the address is
# 3228 Lawton St #1, San Francisco, CA 94122
# *************8the info is
# 3 bds1 ba1,040 sqft
# $+$3,480/mo
# *************7the address is
# The Duboce | 181 Sanchez St, San Francisco, CA
# *************8the info is
# $2,952+ Studio$2,786+ 1 bd$4,528 2 bds
# no price
# *************7the address is
# 923 Folsom | 923 Folsom St, San Francisco, CA
# *************8the info is
# $2,850+ Studio$3,075+ 1 bd$3,981+ 2 bds
# no price
# *************7the address is
# 651 Francisco St, San Francisco, CA 94133
# *************8the info is
# 3 bds2 ba1,100 sqft
# $+$5,995/mo
# *************7the address is
# 126 Thrift St, San Francisco, CA 94112
# *************8the info is
# 1 bd1 ba500 sqft
# $+$1,800/mo
# *************7the address is
# 531 Belvedere St #2, San Francisco, CA 94117
# *************8the info is
# 1 bd1 ba400 sqft
# $+$2,350/mo
# *************7the address is
# 150 Lombard St, San Francisco, CA 94111
# *************8the info is
# 1 bd1 ba1,100 sqft
# $+$5,500/mo
# *************7the address is
# 949 Minnesota St, San Francisco, CA 94107
# *************8the info is
# 3 bds1.5 ba1,200 sqft
# $+$5,100/mo
# *************7the address is
# SoMa Square | 1 Saint Francis Pl, San Francisco, CA
# *************8the info is
# $2,246+ Studio$2,415+ 1 bd$3,126+ 2 bds
# no price
# *************7the address is
# 626 Powell St APT 103, San Francisco, CA 94108
# *************8the info is
# Studio1 ba-- sqft
# $+$2,195/mo
# *************7the address is
# 631 Ofarrell St, San Francisco, CA
# *************8the info is
# $2,150+ Studio
# no price
# *************7the address is
# 1434 Jefferson St, San Francisco, CA 94123
# *************8the info is
# 4 bds3 ba2,800 sqft
# $+$8,995/mo
# *************7the address is
# Solaire | 299 Fremont St, San Francisco, CA
# *************8the info is
# $2,444+ Studio$2,356+ 1 bd$4,025+ 2 bds
# no price
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# <class 'str'>
# @@@@@@@@@@@@@@@@@
# <class 'bs4.element.ResultSet'>
# 40
# *************7the address is
# 940 York St, San Francisco, CA 94110
# *************8the info is
# 4 bds1.5 ba1,600 sqft
# $+$6,300/mo
# *************7the address is
# 318 Maple St, San Francisco, CA
# *************8the info is
# $4,200 2 bds$7,200 3 bds
# no price
# *************7the address is
# 201 Folsom Street Mixed-Use | 201 Folsom St, San Francisco, CA
# *************8the info is
# $2,995 Studio$3,000+ 1 bd$4,999+ 2 bds$11,000+ 3 bds
# no price
# *************7the address is
# 33 Tehama | 33 Tehama St, San Francisco, CA
# *************8the info is
# $2,814+ 1 bd$4,730+ 2 bds
# no price
# *************7the address is
# 1501 44th Ave, San Francisco, CA 94122
# *************8the info is
# 3 bds4 ba2,118 sqft
# $+$5,800/mo
# *************7the address is
# 2608 Sutter St, San Francisco, CA 94115
# *************8the info is
# 2 bds1 ba700 sqft
# $+$3,700/mo
# *************7the address is
# 653 Cayuga Ave, San Francisco, CA 94112
# *************8the info is
# 2 bds2 ba1,300 sqft
# $+$3,350/mo
# *************7the address is
# 1010 Anza St #301, San Francisco, CA 94118
# *************8the info is
# 2 bds1 ba800 sqft
# $+$2,995/mo
# *************7the address is
# 1084 Clay St APT 3, San Francisco, CA 94108
# *************8the info is
# 3 bds2 ba-- sqft
# $+$5,200/mo
# *************7the address is
# 2023 32nd Ave, San Francisco, CA 94116
# *************8the info is
# 3 bds1 ba815 sqft
# $+$3,900/mo
# *************7the address is
# 333 Fremont | 333 Fremont St, San Francisco, CA
# *************8the info is
# $2,735+ 1 bd$3,489+ 2 bds
# no price
# *************7the address is
# 760 6th Ave, San Francisco, CA
# *************8the info is
# $2,300+ 1 bd$3,200 2 bds
# no price
# *************7the address is
# 25 Grace St, San Francisco, CA 94103
# *************8the info is
# 1 bd1 ba-- sqft
# $+$3,000/mo
# *************7the address is
# 1030 York St, San Francisco, CA
# *************8the info is
# $5,300+ 4 bds
# no price
# *************7the address is
# 50 Paulding St #2, San Francisco, CA 94112
# *************8the info is
# 3 bds1 ba1,114 sqft
# $+$3,990/mo
# *************7the address is
# 199 New Montgomery Street Condominiums | 199 New Montgomery St, San Francisco, CA
# *************8the info is
# $2,600 Studio$2,995+ 1 bd$3,700+ 2 bds
# no price
# *************7the address is
# 300 3rd St, San Francisco, CA
# *************8the info is
# $2,400+ Studio$2,895+ 1 bd
# no price
# *************7the address is
# Strata at Mission Bay | 1201 4th St, San Francisco, CA
# *************8the info is
# $2,794+ 1 bd$3,976+ 2 bds
# no price
# *************7the address is
# Venue | 1155 4th St, San Francisco, CA
# *************8the info is
# $2,657+ Studio$3,228+ 1 bd$3,994+ 2 bds
# no price
# *************7the address is
# 433 Dolores St, San Francisco, CA 94110
# *************8the info is
# 3 bds1 ba1,750 sqft
# $+$5,800/mo
# *************7the address is
# 325 Day St, San Francisco, CA 94131
# *************8the info is
# 2 bds1.5 ba1,106 sqft
# $+$4,250/mo
# *************7the address is
# Ashton San Francisco Apartments | 301 Executive Park Blvd, San Francisco, CA
# *************8the info is
# $2,957 Studio$2,683+ 1 bd$3,694+ 2 bds
# no price
# *************7the address is
# 328 5th Ave #2, San Francisco, CA 94118
# *************8the info is
# 2 bds1 ba820 sqft
# $+$2,975/mo
# *************7the address is
# Vara | 1600 15th St, San Francisco, CA
# *************8the info is
# $2,357+ Studio$2,585+ 1 bd$3,322+ 2 bds$4,996+ 3 bds
# no price
# *************7the address is
# 2600 18th St SUITE 24, San Francisco, CA 94110
# *************8the info is
# 2 bds2 ba1,550 sqft
# $+$4,600/mo
# *************7the address is
# 1025 Hyde St, San Francisco, CA
# *************8the info is
# $2,725+ 1 bd
# no price
# *************7the address is
# Potrero Launch | 2235 3rd St, San Francisco, CA
# *************8the info is
# $2,293+ Studio$2,658+ 1 bd$3,821+ 2 bds
# no price
# *************7the address is
# 3228 Lawton St #1, San Francisco, CA 94122
# *************8the info is
# 3 bds1 ba1,040 sqft
# $+$3,480/mo
# *************7the address is
# The Duboce | 181 Sanchez St, San Francisco, CA
# *************8the info is
# $2,952+ Studio$2,786+ 1 bd$4,528 2 bds
# no price
# *************7the address is
# 923 Folsom | 923 Folsom St, San Francisco, CA
# *************8the info is
# $2,850+ Studio$3,075+ 1 bd$3,981+ 2 bds
# no price
# *************7the address is
# 651 Francisco St, San Francisco, CA 94133
# *************8the info is
# 3 bds2 ba1,100 sqft
# $+$5,995/mo
# *************7the address is
# 126 Thrift St, San Francisco, CA 94112
# *************8the info is
# 1 bd1 ba500 sqft
# $+$1,800/mo
# *************7the address is
# 531 Belvedere St #2, San Francisco, CA 94117
# *************8the info is
# 1 bd1 ba400 sqft
# $+$2,350/mo
# *************7the address is
# 150 Lombard St, San Francisco, CA 94111
# *************8the info is
# 1 bd1 ba1,100 sqft
# $+$5,500/mo
# *************7the address is
# 949 Minnesota St, San Francisco, CA 94107
# *************8the info is
# 3 bds1.5 ba1,200 sqft
# $+$5,100/mo
# *************7the address is
# SoMa Square | 1 Saint Francis Pl, San Francisco, CA
# *************8the info is
# $2,246+ Studio$2,415+ 1 bd$3,126+ 2 bds
# no price
# *************7the address is
# 626 Powell St APT 103, San Francisco, CA 94108
# *************8the info is
# Studio1 ba-- sqft
# $+$2,195/mo
# *************7the address is
# 631 Ofarrell St, San Francisco, CA
# *************8the info is
# $2,150+ Studio
# no price
# *************7the address is
# 1434 Jefferson St, San Francisco, CA 94123
# *************8the info is
# 4 bds3 ba2,800 sqft
# $+$8,995/mo
# *************7the address is
# Solaire | 299 Fremont St, San Francisco, CA
# *************8the info is
# $2,444+ Studio$2,356+ 1 bd$4,025+ 2 bds
# no price
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# <class 'str'>
# @@@@@@@@@@@@@@@@@
# <class 'bs4.element.ResultSet'>
# 40
# *************7the address is
# 940 York St, San Francisco, CA 94110
# *************8the info is
# 4 bds1.5 ba1,600 sqft
# $+$6,300/mo
# *************7the address is
# 318 Maple St, San Francisco, CA
# *************8the info is
# $4,200 2 bds$7,200 3 bds
# no price
# *************7the address is
# 201 Folsom Street Mixed-Use | 201 Folsom St, San Francisco, CA
# *************8the info is
# $2,995 Studio$3,000+ 1 bd$4,999+ 2 bds$11,000+ 3 bds
# no price
# *************7the address is
# 33 Tehama | 33 Tehama St, San Francisco, CA
# *************8the info is
# $2,814+ 1 bd$4,730+ 2 bds
# no price
# *************7the address is
# 1501 44th Ave, San Francisco, CA 94122
# *************8the info is
# 3 bds4 ba2,118 sqft
# $+$5,800/mo
# *************7the address is
# 2608 Sutter St, San Francisco, CA 94115
# *************8the info is
# 2 bds1 ba700 sqft
# $+$3,700/mo
# *************7the address is
# 653 Cayuga Ave, San Francisco, CA 94112
# *************8the info is
# 2 bds2 ba1,300 sqft
# $+$3,350/mo
# *************7the address is
# 1010 Anza St #301, San Francisco, CA 94118
# *************8the info is
# 2 bds1 ba800 sqft
# $+$2,995/mo
# *************7the address is
# 1084 Clay St APT 3, San Francisco, CA 94108
# *************8the info is
# 3 bds2 ba-- sqft
# $+$5,200/mo
# *************7the address is
# 2023 32nd Ave, San Francisco, CA 94116
# *************8the info is
# 3 bds1 ba815 sqft
# $+$3,900/mo
# *************7the address is
# 333 Fremont | 333 Fremont St, San Francisco, CA
# *************8the info is
# $2,735+ 1 bd$3,489+ 2 bds
# no price
# *************7the address is
# 760 6th Ave, San Francisco, CA
# *************8the info is
# $2,300+ 1 bd$3,200 2 bds
# no price
# *************7the address is
# 25 Grace St, San Francisco, CA 94103
# *************8the info is
# 1 bd1 ba-- sqft
# $+$3,000/mo
# *************7the address is
# 1030 York St, San Francisco, CA
# *************8the info is
# $5,300+ 4 bds
# no price
# *************7the address is
# 50 Paulding St #2, San Francisco, CA 94112
# *************8the info is
# 3 bds1 ba1,114 sqft
# $+$3,990/mo
# *************7the address is
# 199 New Montgomery Street Condominiums | 199 New Montgomery St, San Francisco, CA
# *************8the info is
# $2,600 Studio$2,995+ 1 bd$3,700+ 2 bds
# no price
# *************7the address is
# 300 3rd St, San Francisco, CA
# *************8the info is
# $2,400+ Studio$2,895+ 1 bd
# no price
# *************7the address is
# Strata at Mission Bay | 1201 4th St, San Francisco, CA
# *************8the info is
# $2,794+ 1 bd$3,976+ 2 bds
# no price
# *************7the address is
# Venue | 1155 4th St, San Francisco, CA
# *************8the info is
# $2,657+ Studio$3,228+ 1 bd$3,994+ 2 bds
# no price
# *************7the address is
# 433 Dolores St, San Francisco, CA 94110
# *************8the info is
# 3 bds1 ba1,750 sqft
# $+$5,800/mo
# *************7the address is
# 325 Day St, San Francisco, CA 94131
# *************8the info is
# 2 bds1.5 ba1,106 sqft
# $+$4,250/mo
# *************7the address is
# Ashton San Francisco Apartments | 301 Executive Park Blvd, San Francisco, CA
# *************8the info is
# $2,957 Studio$2,683+ 1 bd$3,694+ 2 bds
# no price
# *************7the address is
# 328 5th Ave #2, San Francisco, CA 94118
# *************8the info is
# 2 bds1 ba820 sqft
# $+$2,975/mo
# *************7the address is
# Vara | 1600 15th St, San Francisco, CA
# *************8the info is
# $2,357+ Studio$2,585+ 1 bd$3,322+ 2 bds$4,996+ 3 bds
# no price
# *************7the address is
# 2600 18th St SUITE 24, San Francisco, CA 94110
# *************8the info is
# 2 bds2 ba1,550 sqft
# $+$4,600/mo
# *************7the address is
# 1025 Hyde St, San Francisco, CA
# *************8the info is
# $2,725+ 1 bd
# no price
# *************7the address is
# Potrero Launch | 2235 3rd St, San Francisco, CA
# *************8the info is
# $2,293+ Studio$2,658+ 1 bd$3,821+ 2 bds
# no price
# *************7the address is
# 3228 Lawton St #1, San Francisco, CA 94122
# *************8the info is
# 3 bds1 ba1,040 sqft
# $+$3,480/mo
# *************7the address is
# The Duboce | 181 Sanchez St, San Francisco, CA
# *************8the info is
# $2,952+ Studio$2,786+ 1 bd$4,528 2 bds
# no price
# *************7the address is
# 923 Folsom | 923 Folsom St, San Francisco, CA
# *************8the info is
# $2,850+ Studio$3,075+ 1 bd$3,981+ 2 bds
# no price
# *************7the address is
# 651 Francisco St, San Francisco, CA 94133
# *************8the info is
# 3 bds2 ba1,100 sqft
# $+$5,995/mo
# *************7the address is
# 126 Thrift St, San Francisco, CA 94112
# *************8the info is
# 1 bd1 ba500 sqft
# $+$1,800/mo
# *************7the address is
# 531 Belvedere St #2, San Francisco, CA 94117
# *************8the info is
# 1 bd1 ba400 sqft
# $+$2,350/mo
# *************7the address is
# 150 Lombard St, San Francisco, CA 94111
# *************8the info is
# 1 bd1 ba1,100 sqft
# $+$5,500/mo
# *************7the address is
# 949 Minnesota St, San Francisco, CA 94107
# *************8the info is
# 3 bds1.5 ba1,200 sqft
# $+$5,100/mo
# *************7the address is
# SoMa Square | 1 Saint Francis Pl, San Francisco, CA
# *************8the info is
# $2,246+ Studio$2,415+ 1 bd$3,126+ 2 bds
# no price
# *************7the address is
# 626 Powell St APT 103, San Francisco, CA 94108
# *************8the info is
# Studio1 ba-- sqft
# $+$2,195/mo
# *************7the address is
# 631 Ofarrell St, San Francisco, CA
# *************8the info is
# $2,150+ Studio
# no price
# *************7the address is
# 1434 Jefferson St, San Francisco, CA 94123
# *************8the info is
# 4 bds3 ba2,800 sqft
# $+$8,995/mo
# *************7the address is
# Solaire | 299 Fremont St, San Francisco, CA
# *************8the info is
# $2,444+ Studio$2,356+ 1 bd$4,025+ 2 bds
# no price
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# <class 'str'>
# @@@@@@@@@@@@@@@@@
# <class 'bs4.element.ResultSet'>
# 40
# *************7the address is
# 940 York St, San Francisco, CA 94110
# *************8the info is
# 4 bds1.5 ba1,600 sqft
# $+$6,300/mo
# *************7the address is
# 318 Maple St, San Francisco, CA
# *************8the info is
# $4,200 2 bds$7,200 3 bds
# no price
# *************7the address is
# 201 Folsom Street Mixed-Use | 201 Folsom St, San Francisco, CA
# *************8the info is
# $2,995 Studio$3,000+ 1 bd$4,999+ 2 bds$11,000+ 3 bds
# no price
# *************7the address is
# 33 Tehama | 33 Tehama St, San Francisco, CA
# *************8the info is
# $2,814+ 1 bd$4,730+ 2 bds
# no price
# *************7the address is
# 1501 44th Ave, San Francisco, CA 94122
# *************8the info is
# 3 bds4 ba2,118 sqft
# $+$5,800/mo
# *************7the address is
# 2608 Sutter St, San Francisco, CA 94115
# *************8the info is
# 2 bds1 ba700 sqft
# $+$3,700/mo
# *************7the address is
# 653 Cayuga Ave, San Francisco, CA 94112
# *************8the info is
# 2 bds2 ba1,300 sqft
# $+$3,350/mo
# *************7the address is
# 1010 Anza St #301, San Francisco, CA 94118
# *************8the info is
# 2 bds1 ba800 sqft
# $+$2,995/mo
# *************7the address is
# 1084 Clay St APT 3, San Francisco, CA 94108
# *************8the info is
# 3 bds2 ba-- sqft
# $+$5,200/mo
# *************7the address is
# 2023 32nd Ave, San Francisco, CA 94116
# *************8the info is
# 3 bds1 ba815 sqft
# $+$3,900/mo
# *************7the address is
# 333 Fremont | 333 Fremont St, San Francisco, CA
# *************8the info is
# $2,735+ 1 bd$3,489+ 2 bds
# no price
# *************7the address is
# 760 6th Ave, San Francisco, CA
# *************8the info is
# $2,300+ 1 bd$3,200 2 bds
# no price
# *************7the address is
# 25 Grace St, San Francisco, CA 94103
# *************8the info is
# 1 bd1 ba-- sqft
# $+$3,000/mo
# *************7the address is
# 1030 York St, San Francisco, CA
# *************8the info is
# $5,300+ 4 bds
# no price
# *************7the address is
# 50 Paulding St #2, San Francisco, CA 94112
# *************8the info is
# 3 bds1 ba1,114 sqft
# $+$3,990/mo
# *************7the address is
# 199 New Montgomery Street Condominiums | 199 New Montgomery St, San Francisco, CA
# *************8the info is
# $2,600 Studio$2,995+ 1 bd$3,700+ 2 bds
# no price
# *************7the address is
# 300 3rd St, San Francisco, CA
# *************8the info is
# $2,400+ Studio$2,895+ 1 bd
# no price
# *************7the address is
# Strata at Mission Bay | 1201 4th St, San Francisco, CA
# *************8the info is
# $2,794+ 1 bd$3,976+ 2 bds
# no price
# *************7the address is
# Venue | 1155 4th St, San Francisco, CA
# *************8the info is
# $2,657+ Studio$3,228+ 1 bd$3,994+ 2 bds
# no price
# *************7the address is
# 433 Dolores St, San Francisco, CA 94110
# *************8the info is
# 3 bds1 ba1,750 sqft
# $+$5,800/mo
# *************7the address is
# 325 Day St, San Francisco, CA 94131
# *************8the info is
# 2 bds1.5 ba1,106 sqft
# $+$4,250/mo
# *************7the address is
# Ashton San Francisco Apartments | 301 Executive Park Blvd, San Francisco, CA
# *************8the info is
# $2,957 Studio$2,683+ 1 bd$3,694+ 2 bds
# no price
# *************7the address is
# 328 5th Ave #2, San Francisco, CA 94118
# *************8the info is
# 2 bds1 ba820 sqft
# $+$2,975/mo
# *************7the address is
# Vara | 1600 15th St, San Francisco, CA
# *************8the info is
# $2,357+ Studio$2,585+ 1 bd$3,322+ 2 bds$4,996+ 3 bds
# no price
# *************7the address is
# 2600 18th St SUITE 24, San Francisco, CA 94110
# *************8the info is
# 2 bds2 ba1,550 sqft
# $+$4,600/mo
# *************7the address is
# 1025 Hyde St, San Francisco, CA
# *************8the info is
# $2,725+ 1 bd
# no price
# *************7the address is
# Potrero Launch | 2235 3rd St, San Francisco, CA
# *************8the info is
# $2,293+ Studio$2,658+ 1 bd$3,821+ 2 bds
# no price
# *************7the address is
# 3228 Lawton St #1, San Francisco, CA 94122
# *************8the info is
# 3 bds1 ba1,040 sqft
# $+$3,480/mo
# *************7the address is
# The Duboce | 181 Sanchez St, San Francisco, CA
# *************8the info is
# $2,952+ Studio$2,786+ 1 bd$4,528 2 bds
# no price
# *************7the address is
# 923 Folsom | 923 Folsom St, San Francisco, CA
# *************8the info is
# $2,850+ Studio$3,075+ 1 bd$3,981+ 2 bds
# no price
# *************7the address is
# 651 Francisco St, San Francisco, CA 94133
# *************8the info is
# 3 bds2 ba1,100 sqft
# $+$5,995/mo
# *************7the address is
# 126 Thrift St, San Francisco, CA 94112
# *************8the info is
# 1 bd1 ba500 sqft
# $+$1,800/mo
# *************7the address is
# 531 Belvedere St #2, San Francisco, CA 94117
# *************8the info is
# 1 bd1 ba400 sqft
# $+$2,350/mo
# *************7the address is
# 150 Lombard St, San Francisco, CA 94111
# *************8the info is
# 1 bd1 ba1,100 sqft
# $+$5,500/mo
# *************7the address is
# 949 Minnesota St, San Francisco, CA 94107
# *************8the info is
# 3 bds1.5 ba1,200 sqft
# $+$5,100/mo
# *************7the address is
# SoMa Square | 1 Saint Francis Pl, San Francisco, CA
# *************8the info is
# $2,246+ Studio$2,415+ 1 bd$3,126+ 2 bds
# no price
# *************7the address is
# 626 Powell St APT 103, San Francisco, CA 94108
# *************8the info is
# Studio1 ba-- sqft
# $+$2,195/mo
# *************7the address is
# 631 Ofarrell St, San Francisco, CA
# *************8the info is
# $2,150+ Studio
# no price
# *************7the address is
# 1434 Jefferson St, San Francisco, CA 94123
# *************8the info is
# 4 bds3 ba2,800 sqft
# $+$8,995/mo
# *************7the address is
# Solaire | 299 Fremont St, San Francisco, CA
# *************8the info is
# $2,444+ Studio$2,356+ 1 bd$4,025+ 2 bds
# no price
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# <class 'str'>
# @@@@@@@@@@@@@@@@@
# <class 'bs4.element.ResultSet'>
# 40
# *************7the address is
# 940 York St, San Francisco, CA 94110
# *************8the info is
# 4 bds1.5 ba1,600 sqft
# $+$6,300/mo
# *************7the address is
# 318 Maple St, San Francisco, CA
# *************8the info is
# $4,200 2 bds$7,200 3 bds
# no price
# *************7the address is
# 201 Folsom Street Mixed-Use | 201 Folsom St, San Francisco, CA
# *************8the info is
# $2,995 Studio$3,000+ 1 bd$4,999+ 2 bds$11,000+ 3 bds
# no price
# *************7the address is
# 33 Tehama | 33 Tehama St, San Francisco, CA
# *************8the info is
# $2,814+ 1 bd$4,730+ 2 bds
# no price
# *************7the address is
# 1501 44th Ave, San Francisco, CA 94122
# *************8the info is
# 3 bds4 ba2,118 sqft
# $+$5,800/mo
# *************7the address is
# 2608 Sutter St, San Francisco, CA 94115
# *************8the info is
# 2 bds1 ba700 sqft
# $+$3,700/mo
# *************7the address is
# 653 Cayuga Ave, San Francisco, CA 94112
# *************8the info is
# 2 bds2 ba1,300 sqft
# $+$3,350/mo
# *************7the address is
# 1010 Anza St #301, San Francisco, CA 94118
# *************8the info is
# 2 bds1 ba800 sqft
# $+$2,995/mo
# *************7the address is
# 1084 Clay St APT 3, San Francisco, CA 94108
# *************8the info is
# 3 bds2 ba-- sqft
# $+$5,200/mo
# *************7the address is
# 2023 32nd Ave, San Francisco, CA 94116
# *************8the info is
# 3 bds1 ba815 sqft
# $+$3,900/mo
# *************7the address is
# 333 Fremont | 333 Fremont St, San Francisco, CA
# *************8the info is
# $2,735+ 1 bd$3,489+ 2 bds
# no price
# *************7the address is
# 760 6th Ave, San Francisco, CA
# *************8the info is
# $2,300+ 1 bd$3,200 2 bds
# no price
# *************7the address is
# 25 Grace St, San Francisco, CA 94103
# *************8the info is
# 1 bd1 ba-- sqft
# $+$3,000/mo
# *************7the address is
# 1030 York St, San Francisco, CA
# *************8the info is
# $5,300+ 4 bds
# no price
# *************7the address is
# 50 Paulding St #2, San Francisco, CA 94112
# *************8the info is
# 3 bds1 ba1,114 sqft
# $+$3,990/mo
# *************7the address is
# 199 New Montgomery Street Condominiums | 199 New Montgomery St, San Francisco, CA
# *************8the info is
# $2,600 Studio$2,995+ 1 bd$3,700+ 2 bds
# no price
# *************7the address is
# 300 3rd St, San Francisco, CA
# *************8the info is
# $2,400+ Studio$2,895+ 1 bd
# no price
# *************7the address is
# Strata at Mission Bay | 1201 4th St, San Francisco, CA
# *************8the info is
# $2,794+ 1 bd$3,976+ 2 bds
# no price
# *************7the address is
# Venue | 1155 4th St, San Francisco, CA
# *************8the info is
# $2,657+ Studio$3,228+ 1 bd$3,994+ 2 bds
# no price
# *************7the address is
# 433 Dolores St, San Francisco, CA 94110
# *************8the info is
# 3 bds1 ba1,750 sqft
# $+$5,800/mo
# *************7the address is
# 325 Day St, San Francisco, CA 94131
# *************8the info is
# 2 bds1.5 ba1,106 sqft
# $+$4,250/mo
# *************7the address is
# Ashton San Francisco Apartments | 301 Executive Park Blvd, San Francisco, CA
# *************8the info is
# $2,957 Studio$2,683+ 1 bd$3,694+ 2 bds
# no price
# *************7the address is
# 328 5th Ave #2, San Francisco, CA 94118
# *************8the info is
# 2 bds1 ba820 sqft
# $+$2,975/mo
# *************7the address is
# Vara | 1600 15th St, San Francisco, CA
# *************8the info is
# $2,357+ Studio$2,585+ 1 bd$3,322+ 2 bds$4,996+ 3 bds
# no price
# *************7the address is
# 2600 18th St SUITE 24, San Francisco, CA 94110
# *************8the info is
# 2 bds2 ba1,550 sqft
# $+$4,600/mo
# *************7the address is
# 1025 Hyde St, San Francisco, CA
# *************8the info is
# $2,725+ 1 bd
# no price
# *************7the address is
# Potrero Launch | 2235 3rd St, San Francisco, CA
# *************8the info is
# $2,293+ Studio$2,658+ 1 bd$3,821+ 2 bds
# no price
# *************7the address is
# 3228 Lawton St #1, San Francisco, CA 94122
# *************8the info is
# 3 bds1 ba1,040 sqft
# $+$3,480/mo
# *************7the address is
# The Duboce | 181 Sanchez St, San Francisco, CA
# *************8the info is
# $2,952+ Studio$2,786+ 1 bd$4,528 2 bds
# no price
# *************7the address is
# 923 Folsom | 923 Folsom St, San Francisco, CA
# *************8the info is
# $2,850+ Studio$3,075+ 1 bd$3,981+ 2 bds
# no price
# *************7the address is
# 651 Francisco St, San Francisco, CA 94133
# *************8the info is
# 3 bds2 ba1,100 sqft
# $+$5,995/mo
# *************7the address is
# 126 Thrift St, San Francisco, CA 94112
# *************8the info is
# 1 bd1 ba500 sqft
# $+$1,800/mo
# *************7the address is
# 531 Belvedere St #2, San Francisco, CA 94117
# *************8the info is
# 1 bd1 ba400 sqft
# $+$2,350/mo
# *************7the address is
# 150 Lombard St, San Francisco, CA 94111
# *************8the info is
# 1 bd1 ba1,100 sqft
# $+$5,500/mo
# *************7the address is
# 949 Minnesota St, San Francisco, CA 94107
# *************8the info is
# 3 bds1.5 ba1,200 sqft
# $+$5,100/mo
# *************7the address is
# SoMa Square | 1 Saint Francis Pl, San Francisco, CA
# *************8the info is
# $2,246+ Studio$2,415+ 1 bd$3,126+ 2 bds
# no price
# *************7the address is
# 626 Powell St APT 103, San Francisco, CA 94108
# *************8the info is
# Studio1 ba-- sqft
# $+$2,195/mo
# *************7the address is
# 631 Ofarrell St, San Francisco, CA
# *************8the info is
# $2,150+ Studio
# no price
# *************7the address is
# 1434 Jefferson St, San Francisco, CA 94123
# *************8the info is
# 4 bds3 ba2,800 sqft
# $+$8,995/mo
# *************7the address is
# Solaire | 299 Fremont St, San Francisco, CA
# *************8the info is
# $2,444+ Studio$2,356+ 1 bd$4,025+ 2 bds
# no price
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# <class 'str'>
# @@@@@@@@@@@@@@@@@
# <class 'bs4.element.ResultSet'>
# 40
# *************7the address is
# 940 York St, San Francisco, CA 94110
# *************8the info is
# 4 bds1.5 ba1,600 sqft
# $+$6,300/mo
# *************7the address is
# 318 Maple St, San Francisco, CA
# *************8the info is
# $4,200 2 bds$7,200 3 bds
# no price
# *************7the address is
# 201 Folsom Street Mixed-Use | 201 Folsom St, San Francisco, CA
# *************8the info is
# $2,995 Studio$3,000+ 1 bd$4,999+ 2 bds$11,000+ 3 bds
# no price
# *************7the address is
# 33 Tehama | 33 Tehama St, San Francisco, CA
# *************8the info is
# $2,814+ 1 bd$4,730+ 2 bds
# no price
# *************7the address is
# 1501 44th Ave, San Francisco, CA 94122
# *************8the info is
# 3 bds4 ba2,118 sqft
# $+$5,800/mo
# *************7the address is
# 2608 Sutter St, San Francisco, CA 94115
# *************8the info is
# 2 bds1 ba700 sqft
# $+$3,700/mo
# *************7the address is
# 653 Cayuga Ave, San Francisco, CA 94112
# *************8the info is
# 2 bds2 ba1,300 sqft
# $+$3,350/mo
# *************7the address is
# 1010 Anza St #301, San Francisco, CA 94118
# *************8the info is
# 2 bds1 ba800 sqft
# $+$2,995/mo
# *************7the address is
# 1084 Clay St APT 3, San Francisco, CA 94108
# *************8the info is
# 3 bds2 ba-- sqft
# $+$5,200/mo
# *************7the address is
# 2023 32nd Ave, San Francisco, CA 94116
# *************8the info is
# 3 bds1 ba815 sqft
# $+$3,900/mo
# *************7the address is
# 333 Fremont | 333 Fremont St, San Francisco, CA
# *************8the info is
# $2,735+ 1 bd$3,489+ 2 bds
# no price
# *************7the address is
# 760 6th Ave, San Francisco, CA
# *************8the info is
# $2,300+ 1 bd$3,200 2 bds
# no price
# *************7the address is
# 25 Grace St, San Francisco, CA 94103
# *************8the info is
# 1 bd1 ba-- sqft
# $+$3,000/mo
# *************7the address is
# 1030 York St, San Francisco, CA
# *************8the info is
# $5,300+ 4 bds
# no price
# *************7the address is
# 50 Paulding St #2, San Francisco, CA 94112
# *************8the info is
# 3 bds1 ba1,114 sqft
# $+$3,990/mo
# *************7the address is
# 199 New Montgomery Street Condominiums | 199 New Montgomery St, San Francisco, CA
# *************8the info is
# $2,600 Studio$2,995+ 1 bd$3,700+ 2 bds
# no price
# *************7the address is
# 300 3rd St, San Francisco, CA
# *************8the info is
# $2,400+ Studio$2,895+ 1 bd
# no price
# *************7the address is
# Strata at Mission Bay | 1201 4th St, San Francisco, CA
# *************8the info is
# $2,794+ 1 bd$3,976+ 2 bds
# no price
# *************7the address is
# Venue | 1155 4th St, San Francisco, CA
# *************8the info is
# $2,657+ Studio$3,228+ 1 bd$3,994+ 2 bds
# no price
# *************7the address is
# 433 Dolores St, San Francisco, CA 94110
# *************8the info is
# 3 bds1 ba1,750 sqft
# $+$5,800/mo
# *************7the address is
# 325 Day St, San Francisco, CA 94131
# *************8the info is
# 2 bds1.5 ba1,106 sqft
# $+$4,250/mo
# *************7the address is
# Ashton San Francisco Apartments | 301 Executive Park Blvd, San Francisco, CA
# *************8the info is
# $2,957 Studio$2,683+ 1 bd$3,694+ 2 bds
# no price
# *************7the address is
# 328 5th Ave #2, San Francisco, CA 94118
# *************8the info is
# 2 bds1 ba820 sqft
# $+$2,975/mo
# *************7the address is
# Vara | 1600 15th St, San Francisco, CA
# *************8the info is
# $2,357+ Studio$2,585+ 1 bd$3,322+ 2 bds$4,996+ 3 bds
# no price
# *************7the address is
# 2600 18th St SUITE 24, San Francisco, CA 94110
# *************8the info is
# 2 bds2 ba1,550 sqft
# $+$4,600/mo
# *************7the address is
# 1025 Hyde St, San Francisco, CA
# *************8the info is
# $2,725+ 1 bd
# no price
# *************7the address is
# Potrero Launch | 2235 3rd St, San Francisco, CA
# *************8the info is
# $2,293+ Studio$2,658+ 1 bd$3,821+ 2 bds
# no price
# *************7the address is
# 3228 Lawton St #1, San Francisco, CA 94122
# *************8the info is
# 3 bds1 ba1,040 sqft
# $+$3,480/mo
# *************7the address is
# The Duboce | 181 Sanchez St, San Francisco, CA
# *************8the info is
# $2,952+ Studio$2,786+ 1 bd$4,528 2 bds
# no price
# *************7the address is
# 923 Folsom | 923 Folsom St, San Francisco, CA
# *************8the info is
# $2,850+ Studio$3,075+ 1 bd$3,981+ 2 bds
# no price
# *************7the address is
# 651 Francisco St, San Francisco, CA 94133
# *************8the info is
# 3 bds2 ba1,100 sqft
# $+$5,995/mo
# *************7the address is
# 126 Thrift St, San Francisco, CA 94112
# *************8the info is
# 1 bd1 ba500 sqft
# $+$1,800/mo
# *************7the address is
# 531 Belvedere St #2, San Francisco, CA 94117
# *************8the info is
# 1 bd1 ba400 sqft
# $+$2,350/mo
# *************7the address is
# 150 Lombard St, San Francisco, CA 94111
# *************8the info is
# 1 bd1 ba1,100 sqft
# $+$5,500/mo
# *************7the address is
# 949 Minnesota St, San Francisco, CA 94107
# *************8the info is
# 3 bds1.5 ba1,200 sqft
# $+$5,100/mo
# *************7the address is
# SoMa Square | 1 Saint Francis Pl, San Francisco, CA
# *************8the info is
# $2,246+ Studio$2,415+ 1 bd$3,126+ 2 bds
# no price
# *************7the address is
# 626 Powell St APT 103, San Francisco, CA 94108
# *************8the info is
# Studio1 ba-- sqft
# $+$2,195/mo
# *************7the address is
# 631 Ofarrell St, San Francisco, CA
# *************8the info is
# $2,150+ Studio
# no price
# *************7the address is
# 1434 Jefferson St, San Francisco, CA 94123
# *************8the info is
# 4 bds3 ba2,800 sqft
# $+$8,995/mo
# *************7the address is
# Solaire | 299 Fremont St, San Francisco, CA
# *************8the info is
# $2,444+ Studio$2,356+ 1 bd$4,025+ 2 bds
# no price
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# <class 'str'>
# @@@@@@@@@@@@@@@@@
# <class 'bs4.element.ResultSet'>
# 40
# *************7the address is
# 940 York St, San Francisco, CA 94110
# *************8the info is
# 4 bds1.5 ba1,600 sqft
# $+$6,300/mo
# *************7the address is
# 318 Maple St, San Francisco, CA
# *************8the info is
# $4,200 2 bds$7,200 3 bds
# no price
# *************7the address is
# 201 Folsom Street Mixed-Use | 201 Folsom St, San Francisco, CA
# *************8the info is
# $2,995 Studio$3,000+ 1 bd$4,999+ 2 bds$11,000+ 3 bds
# no price
# *************7the address is
# 33 Tehama | 33 Tehama St, San Francisco, CA
# *************8the info is
# $2,814+ 1 bd$4,730+ 2 bds
# no price
# *************7the address is
# 1501 44th Ave, San Francisco, CA 94122
# *************8the info is
# 3 bds4 ba2,118 sqft
# $+$5,800/mo
# *************7the address is
# 2608 Sutter St, San Francisco, CA 94115
# *************8the info is
# 2 bds1 ba700 sqft
# $+$3,700/mo
# *************7the address is
# 653 Cayuga Ave, San Francisco, CA 94112
# *************8the info is
# 2 bds2 ba1,300 sqft
# $+$3,350/mo
# *************7the address is
# 1010 Anza St #301, San Francisco, CA 94118
# *************8the info is
# 2 bds1 ba800 sqft
# $+$2,995/mo
# *************7the address is
# 1084 Clay St APT 3, San Francisco, CA 94108
# *************8the info is
# 3 bds2 ba-- sqft
# $+$5,200/mo
# *************7the address is
# 2023 32nd Ave, San Francisco, CA 94116
# *************8the info is
# 3 bds1 ba815 sqft
# $+$3,900/mo
# *************7the address is
# 333 Fremont | 333 Fremont St, San Francisco, CA
# *************8the info is
# $2,735+ 1 bd$3,489+ 2 bds
# no price
# *************7the address is
# 760 6th Ave, San Francisco, CA
# *************8the info is
# $2,300+ 1 bd$3,200 2 bds
# no price
# *************7the address is
# 25 Grace St, San Francisco, CA 94103
# *************8the info is
# 1 bd1 ba-- sqft
# $+$3,000/mo
# *************7the address is
# 1030 York St, San Francisco, CA
# *************8the info is
# $5,300+ 4 bds
# no price
# *************7the address is
# 50 Paulding St #2, San Francisco, CA 94112
# *************8the info is
# 3 bds1 ba1,114 sqft
# $+$3,990/mo
# *************7the address is
# 199 New Montgomery Street Condominiums | 199 New Montgomery St, San Francisco, CA
# *************8the info is
# $2,600 Studio$2,995+ 1 bd$3,700+ 2 bds
# no price
# *************7the address is
# 300 3rd St, San Francisco, CA
# *************8the info is
# $2,400+ Studio$2,895+ 1 bd
# no price
# *************7the address is
# Strata at Mission Bay | 1201 4th St, San Francisco, CA
# *************8the info is
# $2,794+ 1 bd$3,976+ 2 bds
# no price
# *************7the address is
# Venue | 1155 4th St, San Francisco, CA
# *************8the info is
# $2,657+ Studio$3,228+ 1 bd$3,994+ 2 bds
# no price
# *************7the address is
# 433 Dolores St, San Francisco, CA 94110
# *************8the info is
# 3 bds1 ba1,750 sqft
# $+$5,800/mo
# *************7the address is
# 325 Day St, San Francisco, CA 94131
# *************8the info is
# 2 bds1.5 ba1,106 sqft
# $+$4,250/mo
# *************7the address is
# Ashton San Francisco Apartments | 301 Executive Park Blvd, San Francisco, CA
# *************8the info is
# $2,957 Studio$2,683+ 1 bd$3,694+ 2 bds
# no price
# *************7the address is
# 328 5th Ave #2, San Francisco, CA 94118
# *************8the info is
# 2 bds1 ba820 sqft
# $+$2,975/mo
# *************7the address is
# Vara | 1600 15th St, San Francisco, CA
# *************8the info is
# $2,357+ Studio$2,585+ 1 bd$3,322+ 2 bds$4,996+ 3 bds
# no price
# *************7the address is
# 2600 18th St SUITE 24, San Francisco, CA 94110
# *************8the info is
# 2 bds2 ba1,550 sqft
# $+$4,600/mo
# *************7the address is
# 1025 Hyde St, San Francisco, CA
# *************8the info is
# $2,725+ 1 bd
# no price
# *************7the address is
# Potrero Launch | 2235 3rd St, San Francisco, CA
# *************8the info is
# $2,293+ Studio$2,658+ 1 bd$3,821+ 2 bds
# no price
# *************7the address is
# 3228 Lawton St #1, San Francisco, CA 94122
# *************8the info is
# 3 bds1 ba1,040 sqft
# $+$3,480/mo
# *************7the address is
# The Duboce | 181 Sanchez St, San Francisco, CA
# *************8the info is
# $2,952+ Studio$2,786+ 1 bd$4,528 2 bds
# no price
# *************7the address is
# 923 Folsom | 923 Folsom St, San Francisco, CA
# *************8the info is
# $2,850+ Studio$3,075+ 1 bd$3,981+ 2 bds
# no price
# *************7the address is
# 651 Francisco St, San Francisco, CA 94133
# *************8the info is
# 3 bds2 ba1,100 sqft
# $+$5,995/mo
# *************7the address is
# 126 Thrift St, San Francisco, CA 94112
# *************8the info is
# 1 bd1 ba500 sqft
# $+$1,800/mo
# *************7the address is
# 531 Belvedere St #2, San Francisco, CA 94117
# *************8the info is
# 1 bd1 ba400 sqft
# $+$2,350/mo
# *************7the address is
# 150 Lombard St, San Francisco, CA 94111
# *************8the info is
# 1 bd1 ba1,100 sqft
# $+$5,500/mo
# *************7the address is
# 949 Minnesota St, San Francisco, CA 94107
# *************8the info is
# 3 bds1.5 ba1,200 sqft
# $+$5,100/mo
# *************7the address is
# SoMa Square | 1 Saint Francis Pl, San Francisco, CA
# *************8the info is
# $2,246+ Studio$2,415+ 1 bd$3,126+ 2 bds
# no price
# *************7the address is
# 626 Powell St APT 103, San Francisco, CA 94108
# *************8the info is
# Studio1 ba-- sqft
# $+$2,195/mo
# *************7the address is
# 631 Ofarrell St, San Francisco, CA
# *************8the info is
# $2,150+ Studio
# no price
# *************7the address is
# 1434 Jefferson St, San Francisco, CA 94123
# *************8the info is
# 4 bds3 ba2,800 sqft
# $+$8,995/mo
# *************7the address is
# Solaire | 299 Fremont St, San Francisco, CA
# *************8the info is
# $2,444+ Studio$2,356+ 1 bd$4,025+ 2 bds
# no price
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# <class 'str'>
# @@@@@@@@@@@@@@@@@
# <class 'bs4.element.ResultSet'>
# 40
# *************7the address is
# 940 York St, San Francisco, CA 94110
# *************8the info is
# 4 bds1.5 ba1,600 sqft
# $+$6,300/mo
# *************7the address is
# 318 Maple St, San Francisco, CA
# *************8the info is
# $4,200 2 bds$7,200 3 bds
# no price
# *************7the address is
# 201 Folsom Street Mixed-Use | 201 Folsom St, San Francisco, CA
# *************8the info is
# $2,995 Studio$3,000+ 1 bd$4,999+ 2 bds$11,000+ 3 bds
# no price
# *************7the address is
# 33 Tehama | 33 Tehama St, San Francisco, CA
# *************8the info is
# $2,814+ 1 bd$4,730+ 2 bds
# no price
# *************7the address is
# 1501 44th Ave, San Francisco, CA 94122
# *************8the info is
# 3 bds4 ba2,118 sqft
# $+$5,800/mo
# *************7the address is
# 2608 Sutter St, San Francisco, CA 94115
# *************8the info is
# 2 bds1 ba700 sqft
# $+$3,700/mo
# *************7the address is
# 653 Cayuga Ave, San Francisco, CA 94112
# *************8the info is
# 2 bds2 ba1,300 sqft
# $+$3,350/mo
# *************7the address is
# 1010 Anza St #301, San Francisco, CA 94118
# *************8the info is
# 2 bds1 ba800 sqft
# $+$2,995/mo
# *************7the address is
# 1084 Clay St APT 3, San Francisco, CA 94108
# *************8the info is
# 3 bds2 ba-- sqft
# $+$5,200/mo
# *************7the address is
# 2023 32nd Ave, San Francisco, CA 94116
# *************8the info is
# 3 bds1 ba815 sqft
# $+$3,900/mo
# *************7the address is
# 333 Fremont | 333 Fremont St, San Francisco, CA
# *************8the info is
# $2,735+ 1 bd$3,489+ 2 bds
# no price
# *************7the address is
# 760 6th Ave, San Francisco, CA
# *************8the info is
# $2,300+ 1 bd$3,200 2 bds
# no price
# *************7the address is
# 25 Grace St, San Francisco, CA 94103
# *************8the info is
# 1 bd1 ba-- sqft
# $+$3,000/mo
# *************7the address is
# 1030 York St, San Francisco, CA
# *************8the info is
# $5,300+ 4 bds
# no price
# *************7the address is
# 50 Paulding St #2, San Francisco, CA 94112
# *************8the info is
# 3 bds1 ba1,114 sqft
# $+$3,990/mo
# *************7the address is
# 199 New Montgomery Street Condominiums | 199 New Montgomery St, San Francisco, CA
# *************8the info is
# $2,600 Studio$2,995+ 1 bd$3,700+ 2 bds
# no price
# *************7the address is
# 300 3rd St, San Francisco, CA
# *************8the info is
# $2,400+ Studio$2,895+ 1 bd
# no price
# *************7the address is
# Strata at Mission Bay | 1201 4th St, San Francisco, CA
# *************8the info is
# $2,794+ 1 bd$3,976+ 2 bds
# no price
# *************7the address is
# Venue | 1155 4th St, San Francisco, CA
# *************8the info is
# $2,657+ Studio$3,228+ 1 bd$3,994+ 2 bds
# no price
# *************7the address is
# 433 Dolores St, San Francisco, CA 94110
# *************8the info is
# 3 bds1 ba1,750 sqft
# $+$5,800/mo
# *************7the address is
# 325 Day St, San Francisco, CA 94131
# *************8the info is
# 2 bds1.5 ba1,106 sqft
# $+$4,250/mo
# *************7the address is
# Ashton San Francisco Apartments | 301 Executive Park Blvd, San Francisco, CA
# *************8the info is
# $2,957 Studio$2,683+ 1 bd$3,694+ 2 bds
# no price
# *************7the address is
# 328 5th Ave #2, San Francisco, CA 94118
# *************8the info is
# 2 bds1 ba820 sqft
# $+$2,975/mo
# *************7the address is
# Vara | 1600 15th St, San Francisco, CA
# *************8the info is
# $2,357+ Studio$2,585+ 1 bd$3,322+ 2 bds$4,996+ 3 bds
# no price
# *************7the address is
# 2600 18th St SUITE 24, San Francisco, CA 94110
# *************8the info is
# 2 bds2 ba1,550 sqft
# $+$4,600/mo
# ...
# $+$1,800/mo
# *************7the address is
# 531 Belvedere St #2, San Francisco, CA 94117
# *************8the info is
# 1 bd1 ba400 sqft
# $+$2,350/mo
# *************7the address is
# 150 Lombard St, San Francisco, CA 94111
# *************8the info is
# 1 bd1 ba1,100 sqft
# $+$5,500/mo
# *************7the address is
# 949 Minnesota St, San Francisco, CA 94107
# *************8the info is
# 3 bds1.5 ba1,200 sqft
# $+$5,100/mo
# *************7the address is
# SoMa Square | 1 Saint Francis Pl, San Francisco, CA
# *************8the info is
# $2,246+ Studio$2,415+ 1 bd$3,126+ 2 bds
# no price
# *************7the address is
# 626 Powell St APT 103, San Francisco, CA 94108
# *************8the info is
# Studio1 ba-- sqft
# $+$2,195/mo
# *************7the address is
# 631 Ofarrell St, San Francisco, CA
# *************8the info is
# $2,150+ Studio
# no price
# *************7the address is
# 1434 Jefferson St, San Francisco, CA 94123
# *************8the info is
# 4 bds3 ba2,800 sqft
# $+$8,995/mo
# *************7the address is
# Solaire | 299 Fremont St, San Francisco, CA
# *************8the info is
# $2,444+ Studio$2,356+ 1 bd$4,025+ 2 bds
# no price
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# <class 'str'>
# @@@@@@@@@@@@@@@@@
# <class 'bs4.element.ResultSet'>
# 40
# *************7the address is
# 940 York St, San Francisco, CA 94110
# *************8the info is
# 4 bds1.5 ba1,600 sqft
# $+$6,300/mo
# *************7the address is
# 318 Maple St, San Francisco, CA
# *************8the info is
# $4,200 2 bds$7,200 3 bds
# no price
# *************7the address is
# 201 Folsom Street Mixed-Use | 201 Folsom St, San Francisco, CA
# *************8the info is
# $2,995 Studio$3,000+ 1 bd$4,999+ 2 bds$11,000+ 3 bds
# no price
# *************7the address is
# 33 Tehama | 33 Tehama St, San Francisco, CA
# *************8the info is
# $2,814+ 1 bd$4,730+ 2 bds
# no price
# *************7the address is
# 1501 44th Ave, San Francisco, CA 94122
# *************8the info is
# 3 bds4 ba2,118 sqft
# $+$5,800/mo
# *************7the address is
# 2608 Sutter St, San Francisco, CA 94115
# *************8the info is
# 2 bds1 ba700 sqft
# $+$3,700/mo
# *************7the address is
# 653 Cayuga Ave, San Francisco, CA 94112
# *************8the info is
# 2 bds2 ba1,300 sqft
# $+$3,350/mo
# *************7the address is
# 1010 Anza St #301, San Francisco, CA 94118
# *************8the info is
# 2 bds1 ba800 sqft
# $+$2,995/mo
# *************7the address is
# 1084 Clay St APT 3, San Francisco, CA 94108
# *************8the info is
# 3 bds2 ba-- sqft
# $+$5,200/mo
# *************7the address is
# 2023 32nd Ave, San Francisco, CA 94116
# *************8the info is
# 3 bds1 ba815 sqft
# $+$3,900/mo
# *************7the address is
# 333 Fremont | 333 Fremont St, San Francisco, CA
# *************8the info is
# $2,735+ 1 bd$3,489+ 2 bds
# no price
# *************7the address is
# 760 6th Ave, San Francisco, CA
# *************8the info is
# $2,300+ 1 bd$3,200 2 bds
# no price
# *************7the address is
# 25 Grace St, San Francisco, CA 94103
# *************8the info is
# 1 bd1 ba-- sqft
# $+$3,000/mo
# *************7the address is
# 1030 York St, San Francisco, CA
# *************8the info is
# $5,300+ 4 bds
# no price
# *************7the address is
# 50 Paulding St #2, San Francisco, CA 94112
# *************8the info is
# 3 bds1 ba1,114 sqft
# $+$3,990/mo
# *************7the address is
# 199 New Montgomery Street Condominiums | 199 New Montgomery St, San Francisco, CA
# *************8the info is
# $2,600 Studio$2,995+ 1 bd$3,700+ 2 bds
# no price
# *************7the address is
# 300 3rd St, San Francisco, CA
# *************8the info is
# $2,400+ Studio$2,895+ 1 bd
# no price
# *************7the address is
# Strata at Mission Bay | 1201 4th St, San Francisco, CA
# *************8the info is
# $2,794+ 1 bd$3,976+ 2 bds
# no price
# *************7the address is
# Venue | 1155 4th St, San Francisco, CA
# *************8the info is
# $2,657+ Studio$3,228+ 1 bd$3,994+ 2 bds
# no price
# *************7the address is
# 433 Dolores St, San Francisco, CA 94110
# *************8the info is
# 3 bds1 ba1,750 sqft
# $+$5,800/mo
# *************7the address is
# 325 Day St, San Francisco, CA 94131
# *************8the info is
# 2 bds1.5 ba1,106 sqft
# $+$4,250/mo
# *************7the address is
# Ashton San Francisco Apartments | 301 Executive Park Blvd, San Francisco, CA
# *************8the info is
# $2,957 Studio$2,683+ 1 bd$3,694+ 2 bds
# no price
# *************7the address is
# 328 5th Ave #2, San Francisco, CA 94118
# *************8the info is
# 2 bds1 ba820 sqft
# $+$2,975/mo
# *************7the address is
# Vara | 1600 15th St, San Francisco, CA
# *************8the info is
# $2,357+ Studio$2,585+ 1 bd$3,322+ 2 bds$4,996+ 3 bds
# no price
# *************7the address is
# 2600 18th St SUITE 24, San Francisco, CA 94110
# *************8the info is
# 2 bds2 ba1,550 sqft
# $+$4,600/mo
# *************7the address is
# 1025 Hyde St, San Francisco, CA
# *************8the info is
# $2,725+ 1 bd
# no price
# *************7the address is
# Potrero Launch | 2235 3rd St, San Francisco, CA
# *************8the info is
# $2,293+ Studio$2,658+ 1 bd$3,821+ 2 bds
# no price
# *************7the address is
# 3228 Lawton St #1, San Francisco, CA 94122
# *************8the info is
# 3 bds1 ba1,040 sqft
# $+$3,480/mo
# *************7the address is
# The Duboce | 181 Sanchez St, San Francisco, CA
# *************8the info is
# $2,952+ Studio$2,786+ 1 bd$4,528 2 bds
# no price
# *************7the address is
# 923 Folsom | 923 Folsom St, San Francisco, CA
# *************8the info is
# $2,850+ Studio$3,075+ 1 bd$3,981+ 2 bds
# no price
# *************7the address is
# 651 Francisco St, San Francisco, CA 94133
# *************8the info is
# 3 bds2 ba1,100 sqft
# $+$5,995/mo
# *************7the address is
# 126 Thrift St, San Francisco, CA 94112
# *************8the info is
# 1 bd1 ba500 sqft
# $+$1,800/mo
# *************7the address is
# 531 Belvedere St #2, San Francisco, CA 94117
# *************8the info is
# 1 bd1 ba400 sqft
# $+$2,350/mo
# *************7the address is
# 150 Lombard St, San Francisco, CA 94111
# *************8the info is
# 1 bd1 ba1,100 sqft
# $+$5,500/mo
# *************7the address is
# 949 Minnesota St, San Francisco, CA 94107
# *************8the info is
# 3 bds1.5 ba1,200 sqft
# $+$5,100/mo
# *************7the address is
# SoMa Square | 1 Saint Francis Pl, San Francisco, CA
# *************8the info is
# $2,246+ Studio$2,415+ 1 bd$3,126+ 2 bds
# no price
# *************7the address is
# 626 Powell St APT 103, San Francisco, CA 94108
# *************8the info is
# Studio1 ba-- sqft
# $+$2,195/mo
# *************7the address is
# 631 Ofarrell St, San Francisco, CA
# *************8the info is
# $2,150+ Studio
# no price
# *************7the address is
# 1434 Jefferson St, San Francisco, CA 94123
# *************8the info is
# 4 bds3 ba2,800 sqft
# $+$8,995/mo
# *************7the address is
# Solaire | 299 Fremont St, San Francisco, CA
# *************8the info is
# $2,444+ Studio$2,356+ 1 bd$4,025+ 2 bds
# no price
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# <class 'str'>
# @@@@@@@@@@@@@@@@@
# <class 'bs4.element.ResultSet'>
# 40
# *************7the address is
# 940 York St, San Francisco, CA 94110
# *************8the info is
# 4 bds1.5 ba1,600 sqft
# $+$6,300/mo
# *************7the address is
# 318 Maple St, San Francisco, CA
# *************8the info is
# $4,200 2 bds$7,200 3 bds
# no price
# *************7the address is
# 201 Folsom Street Mixed-Use | 201 Folsom St, San Francisco, CA
# *************8the info is
# $2,995 Studio$3,000+ 1 bd$4,999+ 2 bds$11,000+ 3 bds
# no price
# *************7the address is
# 33 Tehama | 33 Tehama St, San Francisco, CA
# *************8the info is
# $2,814+ 1 bd$4,730+ 2 bds
# no price
# *************7the address is
# 1501 44th Ave, San Francisco, CA 94122
# *************8the info is
# 3 bds4 ba2,118 sqft
# $+$5,800/mo
# *************7the address is
# 2608 Sutter St, San Francisco, CA 94115
# *************8the info is
# 2 bds1 ba700 sqft
# $+$3,700/mo
# *************7the address is
# 653 Cayuga Ave, San Francisco, CA 94112
# *************8the info is
# 2 bds2 ba1,300 sqft
# $+$3,350/mo
# *************7the address is
# 1010 Anza St #301, San Francisco, CA 94118
# *************8the info is
# 2 bds1 ba800 sqft
# $+$2,995/mo
# *************7the address is
# 1084 Clay St APT 3, San Francisco, CA 94108
# *************8the info is
# 3 bds2 ba-- sqft
# $+$5,200/mo
# *************7the address is
# 2023 32nd Ave, San Francisco, CA 94116
# *************8the info is
# 3 bds1 ba815 sqft
# $+$3,900/mo
# *************7the address is
# 333 Fremont | 333 Fremont St, San Francisco, CA
# *************8the info is
# $2,735+ 1 bd$3,489+ 2 bds
# no price
# *************7the address is
# 760 6th Ave, San Francisco, CA
# *************8the info is
# $2,300+ 1 bd$3,200 2 bds
# no price
# *************7the address is
# 25 Grace St, San Francisco, CA 94103
# *************8the info is
# 1 bd1 ba-- sqft
# $+$3,000/mo
# *************7the address is
# 1030 York St, San Francisco, CA
# *************8the info is
# $5,300+ 4 bds
# no price
# *************7the address is
# 50 Paulding St #2, San Francisco, CA 94112
# *************8the info is
# 3 bds1 ba1,114 sqft
# $+$3,990/mo
# *************7the address is
# 199 New Montgomery Street Condominiums | 199 New Montgomery St, San Francisco, CA
# *************8the info is
# $2,600 Studio$2,995+ 1 bd$3,700+ 2 bds
# no price
# *************7the address is
# 300 3rd St, San Francisco, CA
# *************8the info is
# $2,400+ Studio$2,895+ 1 bd
# no price
# *************7the address is
# Strata at Mission Bay | 1201 4th St, San Francisco, CA
# *************8the info is
# $2,794+ 1 bd$3,976+ 2 bds
# no price
# *************7the address is
# Venue | 1155 4th St, San Francisco, CA
# *************8the info is
# $2,657+ Studio$3,228+ 1 bd$3,994+ 2 bds
# no price
# *************7the address is
# 433 Dolores St, San Francisco, CA 94110
# *************8the info is
# 3 bds1 ba1,750 sqft
# $+$5,800/mo
# *************7the address is
# 325 Day St, San Francisco, CA 94131
# *************8the info is
# 2 bds1.5 ba1,106 sqft
# $+$4,250/mo
# *************7the address is
# Ashton San Francisco Apartments | 301 Executive Park Blvd, San Francisco, CA
# *************8the info is
# $2,957 Studio$2,683+ 1 bd$3,694+ 2 bds
# no price
# *************7the address is
# 328 5th Ave #2, San Francisco, CA 94118
# *************8the info is
# 2 bds1 ba820 sqft
# $+$2,975/mo
# *************7the address is
# Vara | 1600 15th St, San Francisco, CA
# *************8the info is
# $2,357+ Studio$2,585+ 1 bd$3,322+ 2 bds$4,996+ 3 bds
# no price
# *************7the address is
# 2600 18th St SUITE 24, San Francisco, CA 94110
# *************8the info is
# 2 bds2 ba1,550 sqft
# $+$4,600/mo
# *************7the address is
# 1025 Hyde St, San Francisco, CA
# *************8the info is
# $2,725+ 1 bd
# no price
# *************7the address is
# Potrero Launch | 2235 3rd St, San Francisco, CA
# *************8the info is
# $2,293+ Studio$2,658+ 1 bd$3,821+ 2 bds
# no price
# *************7the address is
# 3228 Lawton St #1, San Francisco, CA 94122
# *************8the info is
# 3 bds1 ba1,040 sqft
# $+$3,480/mo
# *************7the address is
# The Duboce | 181 Sanchez St, San Francisco, CA
# *************8the info is
# $2,952+ Studio$2,786+ 1 bd$4,528 2 bds
# no price
# *************7the address is
# 923 Folsom | 923 Folsom St, San Francisco, CA
# *************8the info is
# $2,850+ Studio$3,075+ 1 bd$3,981+ 2 bds
# no price
# *************7the address is
# 651 Francisco St, San Francisco, CA 94133
# *************8the info is
# 3 bds2 ba1,100 sqft
# $+$5,995/mo
# *************7the address is
# 126 Thrift St, San Francisco, CA 94112
# *************8the info is
# 1 bd1 ba500 sqft
# $+$1,800/mo
# *************7the address is
# 531 Belvedere St #2, San Francisco, CA 94117
# *************8the info is
# 1 bd1 ba400 sqft
# $+$2,350/mo
# *************7the address is
# 150 Lombard St, San Francisco, CA 94111
# *************8the info is
# 1 bd1 ba1,100 sqft
# $+$5,500/mo
# *************7the address is
# 949 Minnesota St, San Francisco, CA 94107
# *************8the info is
# 3 bds1.5 ba1,200 sqft
# $+$5,100/mo
# *************7the address is
# SoMa Square | 1 Saint Francis Pl, San Francisco, CA
# *************8the info is
# $2,246+ Studio$2,415+ 1 bd$3,126+ 2 bds
# no price
# *************7the address is
# 626 Powell St APT 103, San Francisco, CA 94108
# *************8the info is
# Studio1 ba-- sqft
# $+$2,195/mo
# *************7the address is
# 631 Ofarrell St, San Francisco, CA
# *************8the info is
# $2,150+ Studio
# no price
# *************7the address is
# 1434 Jefferson St, San Francisco, CA 94123
# *************8the info is
# 4 bds3 ba2,800 sqft
# $+$8,995/mo
# *************7the address is
# Solaire | 299 Fremont St, San Francisco, CA
# *************8the info is
# $2,444+ Studio$2,356+ 1 bd$4,025+ 2 bds
# no price
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-8-1cc662921dc0> in <module>
#      30         item_df = item_df.append(pd.DataFrame({'address': [address], 'price': [price], 'info': [info], 'city': [city], 'state': [state]}))
#      31     sleep(5)
# ---> 32     browser.click_link_by_partial_text('Chevron Right')
#      33
#      34 #     for quote in quotes:
#
# ~\anaconda3\lib\site-packages\splinter\driver\__init__.py in click_link_by_partial_text(self, partial_text)
#     394         Clicks in a link by partial content of its text.
#     395         """
# --> 396         return self.find_link_by_partial_text(partial_text).first.click()
#     397
#     398     def click_link_by_id(self, id):
#
# ~\anaconda3\lib\site-packages\splinter\driver\webdriver\__init__.py in find_link_by_partial_text(self, partial_text)
#     528             FutureWarning,
#     529         )
# --> 530         return self.links.find_by_partial_text(partial_text)
#     531
#     532     def find_link_by_text(self, text):
#
# ~\anaconda3\lib\site-packages\splinter\driver\webdriver\__init__.py in find_by_partial_text(self, partial_text)
#     213             '//a[contains(normalize-space(.), "{}")]'.format(partial_text),
#     214             original_find="link by partial text",
# --> 215             original_query=partial_text,
#     216         )
#     217
#
# ~\anaconda3\lib\site-packages\splinter\driver\webdriver\__init__.py in find_by_xpath(self, xpath, original_find, original_query, wait_time)
#     555             original_find=original_find,
#     556             original_query=original_query,
# --> 557             wait_time=wait_time,
#     558         )
#     559
#
# ~\anaconda3\lib\site-packages\splinter\driver\webdriver\__init__.py in find_by(self, finder, selector, original_find, original_query, wait_time)
#     279
#     280         while time.time() < end_time:
# --> 281             elem_list = _find(self, finder, selector)
#     282
#     283             if elem_list:
#
# ~\anaconda3\lib\site-packages\splinter\driver\webdriver\__init__.py in _find(self, finder, selector)
#     239
#     240     try:
# --> 241         elements = finder(selector)
#     242         if not isinstance(elements, list):
#     243             elements = [elements]
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_elements_by_xpath(self, xpath)
#     408             elements = driver.find_elements_by_xpath("//div[contains(@class, 'foo')]")
#     409         """
# --> 410         return self.find_elements(by=By.XPATH, value=xpath)
#     411
#     412     def find_element_by_link_text(self, link_text):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_elements(self, by, value)
#    1005         return self.execute(Command.FIND_ELEMENTS, {
#    1006             'using': by,
# -> 1007             'value': value})['value'] or []
#    1008
#    1009     @property
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: chrome not reachable
#   (Session info: chrome=84.0.4147.105)
#   (Driver info: chromedriver=2.34.522940 (1a76f96f66e3ca7b8e57d503b4dd3bccfba87af1),platform=Windows NT 10.0.18363 x86_64)

# %%
item_df.to_excel('housing.xlsx', sheet_name= 'housing')
