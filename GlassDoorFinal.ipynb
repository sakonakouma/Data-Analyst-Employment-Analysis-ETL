# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import os
from config import census_key
import json
import requests 
#from census import Census

# %%
# Import DA Job csv
da_job = pd.read_csv("Resources/DataAnalyst.csv")

# Drop unnecessary columns
da_job_data = da_job[["ID", "Job Title", "Salary Estimate", "Job Description", "Rating", "Company Name", "Location", "Headquarters", "Size", 
                                     "Founded", "Type of ownership", "Industry", "Sector", "Revenue", "Competitors", "Easy Apply"]]
# create df
da_job_data_df = pd.DataFrame(da_job_data)

# drop columns
gd_df = da_job_data_df.drop(['Easy Apply'], axis=1)

# %%
# Determine top 50 cities with data analyst jobs

# group by city
t50 = gd_df.groupby('Location').count()["ID"]

#create df
t50_df = pd.DataFrame({"gaJobs": t50})

#reset index
t50_df = t50_df.reset_index(drop=False)

# sort data
t50_df = t50_df.sort_values(['gaJobs', 'Location'], ascending=[False, True]).head(50)

# %%
# join 2 tables to filter job table by top 50 city

gd_t50_df = gd_df.merge(t50_df,how='right', left_on='Location', right_on='Location')

# drop columns

gd_t50_df = gd_t50_df.drop(['gaJobs'], axis=1)

# export to csv
gd_t50_df.to_csv ("glassdoorfinal.csv", index = False, header=True)
gd_t50_df
# Out:
#         ID                                          Job Title  \
# 0        0  Data Analyst, Center on Immigration and Justic...
# 1        1                               Quality Data Analyst
# 2        2  Senior Data Analyst, Insights & Analytics Team...
# 3        3                                       Data Analyst
# 4        4                             Reporting Data Analyst
# ...    ...                                                ...
# 1801  2213                Data Analyst 3, Customer Experience
# 1802  2242                      Business Systems Analyst-Data
# 1803  2245            Data Analyst Supporting the DEA #20-242
# 1804  2249              Senior Data Analyst (Corporate Audit)
# 1805  2251                Data Analyst 3, Customer Experience
#
#                   Salary Estimate  \
# 0      $37K-$66K (Glassdoor est.)
# 1      $37K-$66K (Glassdoor est.)
# 2      $37K-$66K (Glassdoor est.)
# 3      $37K-$66K (Glassdoor est.)
# 4      $37K-$66K (Glassdoor est.)
# ...                           ...
# 1801  $57K-$100K (Glassdoor est.)
# 1802  $78K-$104K (Glassdoor est.)
# 1803  $78K-$104K (Glassdoor est.)
# 1804  $78K-$104K (Glassdoor est.)
# 1805  $78K-$104K (Glassdoor est.)
#
#                                         Job Description  Rating  \
# 0     Are you eager to roll up your sleeves and harn...     3.2
# 1     Overview\n\nProvides analytical and technical ...     3.8
# 2     We’re looking for a Senior Data Analyst who ha...     3.4
# 3     Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4     ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
# ...                                                 ...     ...
# 1801  Business Unit:SummaryResponsible for working c...     3.6
# 1802  Location Centennial, CO Description Our client...     3.5
# 1803  Salary:\nPublished Job Title:\nData Analyst Su...     2.8
# 1804  Position:\nSenior Data Analyst (Corporate Audi...     2.9
# 1805  Summary\n\nResponsible for working cross-funct...     3.1
#
#                                  Company Name        Location  \
# 0              Vera Institute of Justice\n3.2    New York, NY
# 1     Visiting Nurse Service of New York\n3.8    New York, NY
# 2                            Squarespace\n3.4    New York, NY
# 3                               Celerity\n4.1    New York, NY
# 4                                FanDuel\n3.9    New York, NY
# ...                                       ...             ...
# 1801                             Comcast\n3.6  Centennial, CO
# 1802               The Judge Group, Inc.\n3.5  Centennial, CO
# 1803       Forfeiture Support Associates\n2.8  Centennial, CO
# 1804                   Arrow Electronics\n2.9  Centennial, CO
# 1805         Contingent Network Services\n3.1  Centennial, CO
#
#           Headquarters                    Size  Founded  \
# 0         New York, NY    201 to 500 employees     1961
# 1         New York, NY        10000+ employees     1893
# 2         New York, NY  1001 to 5000 employees     2003
# 3           McLean, VA    201 to 500 employees     2002
# 4         New York, NY   501 to 1000 employees     2009
# ...                ...                     ...      ...
# 1801  Philadelphia, PA        10000+ employees     1963
# 1802         Wayne, PA  1001 to 5000 employees     1970
# 1803       Ashburn, VA  1001 to 5000 employees     2004
# 1804    Centennial, CO        10000+ employees     1935
# 1805  West Chester, OH    201 to 500 employees     1984
#
#                    Type of ownership                                 Industry  \
# 0             Nonprofit Organization                        Social Assistance
# 1             Nonprofit Organization         Health Care Services & Hospitals
# 2                  Company - Private                                 Internet
# 3     Subsidiary or Business Segment                              IT Services
# 4                  Company - Private                      Sports & Recreation
# ...                              ...                                      ...
# 1801                Company - Public                                       -1
# 1802               Company - Private                   Staffing & Outsourcing
# 1803               Company - Private                   Staffing & Outsourcing
# 1804                Company - Public                                Wholesale
# 1805               Company - Private  Enterprise Software & Network Solutions
#
#                                 Sector                     Revenue  \
# 0                           Non-Profit  $100 to $500 million (USD)
# 1                          Health Care      $2 to $5 billion (USD)
# 2               Information Technology    Unknown / Non-Applicable
# 3               Information Technology   $50 to $100 million (USD)
# 4     Arts, Entertainment & Recreation  $100 to $500 million (USD)
# ...                                ...                         ...
# 1801                                -1          $10+ billion (USD)
# 1802                 Business Services  $100 to $500 million (USD)
# 1803                 Business Services   $50 to $100 million (USD)
# 1804                 Business Services          $10+ billion (USD)
# 1805            Information Technology    $25 to $50 million (USD)
#
#                          Competitors
# 0                                 -1
# 1                                 -1
# 2                            GoDaddy
# 3                                 -1
# 4                         DraftKings
# ...                              ...
# 1801                   AT&T, Verizon
# 1802                  Adecco, Kforce
# 1803                              -1
# 1804  Avnet, Ingram Micro, Tech Data
# 1805                              -1
#
# [1806 rows x 15 columns]

# %%
# reset index
t50_df.reset_index(drop=True, inplace=True)

# split city and state into own columns
t50_df[['City','State']] = t50_df.Location.str.split(",",expand=True,)

# drop columns
t50_df = t50_df.drop(['gaJobs'], axis=1)

# export to csv
t50_df.to_csv ("top50city.csv", index = False, header=True) 
t50_df
# Out:
#               Location            City State
# 0         New York, NY        New York    NY
# 1          Chicago, IL         Chicago    IL
# 2    San Francisco, CA   San Francisco    CA
# 3           Austin, TX          Austin    TX
# 4      Los Angeles, CA     Los Angeles    CA
# 5        Charlotte, NC       Charlotte    NC
# 6          Houston, TX         Houston    TX
# 7           Dallas, TX          Dallas    TX
# 8        San Diego, CA       San Diego    CA
# 9     Philadelphia, PA    Philadelphia    PA
# 10          Denver, CO          Denver    CO
# 11     San Antonio, TX     San Antonio    TX
# 12        San Jose, CA        San Jose    CA
# 13         Phoenix, AZ         Phoenix    AZ
# 14     Jersey City, NJ     Jersey City    NJ
# 15           Tempe, AZ           Tempe    AZ
# 16         Seattle, WA         Seattle    WA
# 17        Columbus, OH        Columbus    OH
# 18          Irving, TX          Irving    TX
# 19           Plano, TX           Plano    TX
# 20  Salt Lake City, UT  Salt Lake City    UT
# 21     Santa Clara, CA     Santa Clara    CA
# 22      El Segundo, CA      El Segundo    CA
# 23    Jacksonville, FL    Jacksonville    FL
# 24         Norfolk, VA         Norfolk    VA
# 25       San Mateo, CA       San Mateo    CA
# 26         Burbank, CA         Burbank    CA
# 27    Indianapolis, IN    Indianapolis    IN
# 28      Fort Worth, TX      Fort Worth    TX
# 29       Sunnyvale, CA       Sunnyvale    CA
# 30   Mountain View, CA   Mountain View    CA
# 31      Scottsdale, AZ      Scottsdale    AZ
# 32       Palo Alto, CA       Palo Alto    CA
# 33        Brooklyn, NY        Brooklyn    NY
# 34       Cupertino, CA       Cupertino    CA
# 35         Hampton, VA         Hampton    VA
# 36      Long Beach, CA      Long Beach    CA
# 37    Redwood City, CA    Redwood City    CA
# 38      Menlo Park, CA      Menlo Park    CA
# 39         Oakland, CA         Oakland    CA
# 40         Redmond, WA         Redmond    WA
# 41      Wilmington, DE      Wilmington    DE
# 42      Richardson, TX      Richardson    TX
# 43      Centennial, CO      Centennial    CO
# 44   Downers Grove, IL   Downers Grove    IL
# 45     Foster City, CA     Foster City    CA
# 46    Lake Success, NY    Lake Success    NY
# 47    Santa Monica, CA    Santa Monica    CA
# 48       Arlington, TX       Arlington    TX
# 49        Glendale, CA        Glendale    CA

# %%
# Confirm unique city names

unique_city = len(t50_df["City"].unique())
print(unique_city)

# can use city as foreign key
# Out:
# 50
